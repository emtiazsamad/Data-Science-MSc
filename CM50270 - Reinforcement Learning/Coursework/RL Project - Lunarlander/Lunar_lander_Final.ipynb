# %% [markdown]
# # CM50270 Reinforcement Learning Project
#
# ### Lunar Lander V2

# %% [markdown]
# ## Importing Dependencies

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import time
from collections import deque
import gym

import tensorflow as tf2
from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Dense, Embedding, Reshape, Lambda
from tensorflow.keras.optimizers import Adam

from matplotlib import animation, rc
from matplotlib.animation import FuncAnimation
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay
from IPython.display import HTML, clear_output

# %%
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only
import random
import math
import glob
import logging
import io
import base64

import keras
import tensorflow as tf2
from keras import backend as K
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/mk/6dqc1l9n1hd216kbwtlcskyw0000gn/T/ipykernel_62418/470521748.py in <module>
#       1 from gym import logger as gymlogger
# ----> 2 from gym.wrappers import Monitor
#       3 gymlogger.set_level(40) #error only
#       4 import random
#       5 import math
#
# ImportError: cannot import name 'Monitor' from 'gym.wrappers' (/Users/emtiazsamad/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/gym/wrappers/__init__.py)

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions.categorical import Categorical
import timeit

# %%
def render(episode, env, m_name, n_ep):
    
    fig = plt.figure()
    img = plt.imshow(env.render(mode='rgb_array'))
    plt.axis('off')

    def animate(i):
        img.set_data(episode[i])
        return img,
    
    mp4 = os.getcwd() + '/' + str(m_name) + ' Videos/' + str(m_name) + '_' + str(n_ep) +'.mp4'
    anim = FuncAnimation(fig, animate, frames=len(episode), interval=1, blit=True)
    Writer = animation.writers['ffmpeg']
    writer = Writer(fps = 50, metadata = dict(artist = 'Me'), bitrate = 1800)
    anim.save(mp4, writer = writer, dpi=100)

    html =  HTML(anim.to_html5_video())

    plt.close(fig)
    
    return html

def save_video(episodes_frames, methods, env):
    path = os.getcwd() + '/' + methods + ' Videos'
    if not os.path.exists(path):
        os.makedirs(path)
        
    for i in range(len(episodes_frames)):
        render(episodes_frames[i], env, methods, i)

# %% [markdown]
# ## Implementing REINFORCE Algorithm with Adaptive Baseline

# %%
class RLAgent(object):
    
    def __init__(self, obs_space, action_space, policy_learning_rate, value_learning_rate, 
                 discount, baseline = None, num_layers=3, ma_window_size=50):

        # input/output
        self.num_obs = obs_space  
        self.num_act = action_space.n
        
        # training parameters
        self.plr = policy_learning_rate
        self.vlr = value_learning_rate
        self.gamma = discount
        self.num_layers = num_layers
        self.ma_window_size = ma_window_size
    
        # lists to store the cumulative observations for an episode
        self.eps_observations = []
        self.eps_actions = []
        self.eps_rewards = []

        # set baseline
        if baseline == 'adaptive':
            self.use_adaptive_baseline = True
        else:
            self.use_adaptive_baseline = False

        # build the keras network/s
        self.network()

    def observe(self, state, action, reward):
        """ This function takes the observations the agent received from the environment and stores them
            in the lists above."""

        self.eps_observations.append(state)
        self.eps_actions.append(action)
        self.eps_rewards.append(reward)
        
    def get_action(self, state):
        """ This function feeds the observed state to the network, which returns a distribution
            over possible actions. Sample an action from the distribution and return it."""
        
        if np.random.random() < self.epsilon:
            action = np.random.choice(self.action_size)
        else:
            state = state.reshape([1, self.num_obs])
            action_probabilities = self.model(state).numpy().flatten()
            action = np.random.choice(self.num_act, p=action_probabilities)


        return action

    def train(self):
        """ When this function is called, the accumulated episode observations, actions and discounted rewards
            should be fed into the network and used for training. Use the _get_returns function to first turn 
            the episode rewards into discounted returns. 
            Apply simple or adaptive baselines if needed, depending on parameters."""

        episode_length = len(self.eps_observations)

        # States
        obs_states=np.array(self.eps_observations)

        # Actions (hot encoding)
        mask = np.eye(self.num_act) #unit matric
        actions = mask[self.eps_actions]

        # Discounted Rewards
        discounted_rewards = np.array(self.returns())
                    
        if self.use_adaptive_baseline:
            
            # update model_baseline parameters
            self.model_baseline.train_on_batch(x = obs_states, y = discounted_rewards)
            
            # subtract Baseline
            discounted_rewards -= self.model_baseline(obs_states).numpy().flatten() #advantage
        
        # update model (policy) parameters weights
        self.model.train_on_batch(x = obs_states, y = actions, sample_weight = discounted_rewards)
        
        # reset cumulative lists
        self.eps_observations = []
        self.eps_actions = []
        self.eps_rewards = []

    def returns(self):
        """ This function should process self.episode_rewards and return the discounted episode returns
            at each step in the episode. """ 
               
        discounted_rewards = []
        cum_return = 0

        #a[::-1] reverse the list
        for r in self.eps_rewards[::-1]:  
            cum_return = (cum_return*self.gamma) + r
            discounted_rewards.insert(0, cum_return) #insert as the first value
    
        return discounted_rewards


    def network(self):
        """ This function should build the network that can then be called by decide and train. 
            The network takes observations as inputs and has a policy distribution as output."""

        model = Sequential()
        for i in tf2.range(self.num_layers):
            model.add(Dense(16, activation="relu"))
        model.add(Dense(self.num_act, activation="softmax")) 
        
        model.compile(loss = "categorical_crossentropy", optimizer = Adam(learning_rate=self.plr))
        self.model = model

        if self.use_adaptive_baseline == True:
            model_baseline = Sequential()
            for i in tf2.range(self.num_layers):
                  model_baseline.add(Dense(16, activation="relu"))
            model_baseline.add(Dense(1)) 
        
            model_baseline.compile(loss = "mse", optimizer = Adam(learning_rate=self.vlr))
            self.model_baseline = model_baseline

# %%
def run_experiment(experiment_name, env, num_episodes, policy_learning_rate=0.001, value_learning_rate=0.001, baseline=None, 
                   num_layers=3):

    #Initiate the learning agent
    agent = RLAgent(obs_space=env.observation_space.shape[0], action_space=env.action_space, policy_learning_rate=policy_learning_rate, 
                    value_learning_rate=value_learning_rate, discount=0.99, baseline=baseline, num_layers=num_layers)

    rewards = []
    all_eps_frames = []
    step = 0
    time_list = []
    
    #loop each episode
    for episode in range(1, num_episodes+1):
    
        #Update results plot and occasionally store an episode movie
        eps_frames = None
        start = time.time()

        if (episode < 10) or (episode>=989 and episode<=999) or (episode>=1989 and episode<=1999):
            eps_frames = []
            
        #initialise, Reset the environment to a new episode
        observation = env.reset()
        episode_reward = 0
        
        #loop each step 
        while True:
            #occasionally store an episode movie
            if eps_frames is not None:
                eps_frames.append(env.render(mode='rgb_array'))

            # 1. Decide on an next action based on the observations
            action = agent.get_action(observation)

            # 2. Take action in the environment
            next_observation, reward, done, info = env.step(action)
            episode_reward += reward

            # 3. Store the information returned from the environment for training the model
            agent.observe(observation, action, reward)

            # 4. When we reach a terminal state ("done"), use the observed episode to train the network
            if done:
                end = time.time()
                time_list.append(end - start)
                
                rewards.append(episode_reward)
                if episode % 10 == 0:
                    print("episode: {}/{}, reward: {}".format(episode, num_episodes, episode_reward))
                    
                if eps_frames is not None:
                    all_eps_frames.append(eps_frames)
                    
                if (episode % 100 == 0) or episode == 1:
                    agent.model.save(('REINFORCE Networks/reinforce_model_{}'.format(episode)))
                
                agent.train() #each epo done then train the model
                break

            # Reset for next step
            observation = next_observation
            step += 1
            
    results[experiment_name] = np.array(rewards)
    
    return all_eps_frames, agent, time_list

# %%
def test_experiment(env, num_episodes, policy_learning_rate=0.001, value_learning_rate=0.001, baseline=None, 
                   num_layers=3, file = ''):
    
    lunar_env = env
    agent = RLAgent(obs_space=lunar_env.observation_space.shape[0], action_space=lunar_env.action_space, policy_learning_rate=policy_learning_rate, 
                    value_learning_rate=value_learning_rate, discount=0.99, baseline=baseline, num_layers=num_layers)
      
    rf_model = tf.keras.models.load_model(file)
    step = 0
    agent.model = rf_model
    
    rewards, average_reward, all_eps_frames = [], [], []
   
    eps_frames = None

    #loop each episode
    for episode in range(1, num_episodes+1):
        eps_frames = []
            
        #initialise, Reset the environment to a new episode
        observation = lunar_env.reset()
        episode_reward = 0
        
        #loop each step 
        while True:
            #occasionally store an episode movie
            if eps_frames is not None:
                eps_frames.append(env.render(mode='rgb_array'))

            # 1. Decide on an next action based on the observations
            action = agent.get_action(observation)

            # 2. Take action in the environment
            next_observation, reward, done, info = env.step(action)
            episode_reward += reward


            # 4. When we reach a terminal state ("done"), use the observed episode to train the network
            if done:
                rewards.append(episode_reward)
                print("episode: {}/{}, reward: {}".format(episode, num_episodes, episode_reward))
                    
                if eps_frames is not None:
                    all_eps_frames.append(eps_frames)
             
                break

            # Reset for next step
            observation = next_observation
            step += 1
    
    return all_eps_frames, np.array(rewards)

# %% [markdown]
# ### Gym Setup
#
# Here we load the Reinforcement Learning environments from Gym.
#
# We limit each episode to 500 steps so that we can train faster.

# %%
num_episodes = 2000

# %%
lunar_env = gym.make('LunarLander-v2')
lunar_env._max_episode_steps = 1000

# %matplotlib inline
plt.rcParams['figure.figsize'] = 12, 8

# %% [markdown]
# ### Run the experiment

# %%
results = {}

# %%
run_experiment("REINFORCE (adaptive baseline)", lunar_env, 100, policy_learning_rate, 
                                   value_learning_rate, baseline='adaptive')
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras model <tensorflow.python.keras.engine.sequential.Sequential object at 0x7fccd7d7d110>, because its inputs are not defined.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/mk/6dqc1l9n1hd216kbwtlcskyw0000gn/T/ipykernel_62418/3287926232.py in <module>
#       1 run_experiment("REINFORCE (adaptive baseline)", lunar_env, 100, policy_learning_rate,
# ----> 2                                    value_learning_rate, baseline='adaptive')
#
# /var/folders/mk/6dqc1l9n1hd216kbwtlcskyw0000gn/T/ipykernel_62418/598444356.py in run_experiment(experiment_name, env, num_episodes, policy_learning_rate, value_learning_rate, baseline, num_layers)
#      54
#      55                 if (episode % 100 == 0) or episode == 1:
# ---> 56                     agent.model.save(('REINFORCE Networks/reinforce_model_{}'.format(episode)))
#      57
#      58                 agent.train() #each epo done then train the model
#
# ~/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options)
#     973     """
#     974     saving.save_model(self, filepath, overwrite, include_optimizer, save_format,
# --> 975                       signatures, options)
#     976
#     977   def save_weights(self, filepath, overwrite=True, save_format=None):
#
# ~/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options)
#     113   else:
#     114     saved_model_save.save(model, filepath, overwrite, include_optimizer,
# --> 115                           signatures, options)
#     116
#     117
#
# ~/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/saved_model/save.py in save(model, filepath, overwrite, include_optimizer, signatures, options)
#      63
#      64   if save_impl.should_skip_serialization(model):
# ---> 65     saving_utils.raise_model_input_error(model)
#      66
#      67   if not include_optimizer:
#
# ~/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/saving_utils.py in raise_model_input_error(model)
#     104       'set. Usually, input shapes are automatically determined from calling'
#     105       ' .fit() or .predict(). To manually set the shapes, call '
# --> 106       'model._set_inputs(inputs).'.format(model))
#     107
#     108
#
# ValueError: Model <tensorflow.python.keras.engine.sequential.Sequential object at 0x7fccd7d7d110> cannot be saved because the input shapes have not been set. Usually, input shapes are automatically determined from calling .fit() or .predict(). To manually set the shapes, call model._set_inputs(inputs).

# %%
# save_video(episodes_reinforce, 'REINFORCE', lunar_env)

# %%
lunar_env.close()

# %%
'''RUN CELL AND UNCOMMENT LAST LINE IF MODEL HAS BEEN TRAINED, OTHERWISE IGNORE'''
df_RF = pd.DataFrame()
df_RF['Reward'] = results['REINFORCE (adaptive baseline)']
df_RF['time'] = time_reinforce
df_RF.to_csv('REINFORCE Rewards.csv')

# %%
test_1,rewards_1 =test_experiment(lunar_env, 3, policy_learning_rate, value_learning_rate, baseline='adaptive', \
                file = 'REINFORCE Networks/reinforce_model_1')

test_20,rewards_20 =test_experiment(lunar_env, 3, policy_learning_rate, value_learning_rate, baseline='adaptive', \
                file = 'REINFORCE Networks/reinforce_model_2000')
# Out:
# episode: 1/3, reward: -167.48339800491846
# episode: 2/3, reward: -129.23571725111867
# episode: 3/3, reward: -82.61316184229042
# episode: 1/3, reward: -17.337860142930197
# episode: 2/3, reward: 137.3630535997707
# episode: 3/3, reward: 36.5630234737969

# %%
episodes_reinforce_test = []

episodes_clip = []
for i in range(3):
    episodes_clip += test_1[i]
episodes_reinforce_test.append(episodes_clip)

episodes_clip = []
for i in range(3):
    episodes_clip += test_20[i]
episodes_reinforce_test.append(episodes_clip)

# %%
# save_video(episodes_reinforce_test, 'REINFORCE test', lunar_env)

# %% [markdown]
# ## ⭐ Implementing DDQN (Double DQN) Algorithm with Experience Replay

# %%
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\johng\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
def network(opt, input_dim, action_size):
    network = Sequential()
    network.add(Dense(128, input_dim = input_dim, activation = "relu"))
    network.add(Dense(128, activation = "relu"))
    network.add(Dense(action_size, activation = "linear"))
    network.compile(optimizer = opt, loss = 'mse')
    return network

class DDQNAgent:
    def __init__(self, env, optimizer, batch_size, gamma=0.99, epsilon=1, decay=0.995):
        self.env = env
        self.optimizer = optimizer
        self.batch_size = batch_size
        self.gamma = gamma
        self.epsilon = epsilon
        self.decay = decay
        
        self.state_size = env.observation_space.shape[0]
        self.action_size = env.action_space.n
        
        self.exp_replay = deque(maxlen=1000000)
        
        self.qnetwork = network(self.optimizer, self.state_size, self.action_size)
        self.target = network(self.optimizer, self.state_size, self.action_size)
        
        self.rewards = None
        self.average_reward = None
        self.ep_time = []
        self.cumulative_time = []

    def policy(self, state):
        if np.random.random() < self.epsilon:
            action = np.random.choice(self.action_size)
        else:
            state = np.reshape(state, [1, self.state_size])
            actions = self.qnetwork.predict(state)
            action = np.argmax(actions[0])
        return action
    
    def add_memory(self, state, action, reward, next_state, terminal):
        self.exp_replay.append((state, action, reward, next_state, terminal))
    
    def update_target(self):
        return self.target.set_weights(self.qnetwork.get_weights())
    
    def train(self):
        batch_size = min(len(self.exp_replay), self.batch_size)
        batch = random.sample(self.exp_replay, batch_size)
        
        states = np.ndarray((batch_size, self.state_size))
        next_states = states.copy()
        
        actions = np.ndarray((batch_size, 1))
        rewards = actions.copy()
        terminals = actions.copy()
        
        step = 0
        for memory in batch:
            states[step], actions[step], rewards[step], next_states[step], terminals[step] = memory
            step += 1
         
        q_next = self.target.predict(next_states) * (np.ones(shape = terminals.shape) - terminals)
        q_next = np.max(q_next, axis=1)
        q = self.qnetwork.predict(states)
        
        for i in range(batch_size):
            q[i,int(actions[i,0])] = rewards[i] + self.gamma * q_next[i]
            
        self.qnetwork.fit(states, q, verbose = 0)
    
    def train_model(self, env, num_episodes):
        
        count = 0
        rewards, average_reward = [], []
        
        
        average = deque(maxlen=100)
        
        txt = open('Saved Networks.txt', 'w')
        path = os.getcwd() + '/Saved Networks'
        if not os.path.exists(path):
            os.makedirs(path)
        
        cumulative_start = time.time()

        for episode in range(1, num_episodes + 1):
            ep_start = time.time()
            state = env.reset()
            total = 0
            terminal = False
            
            while not terminal:
                action = self.policy(state)
                next_state, reward, terminal, _ = env.step(action)
                
                total += reward
                
                self.add_memory(state, action, reward, next_state, terminal)
                self.train()
                state = next_state
                
        
            average.append(total)
            average_reward.append(np.mean(average))
            rewards.append(total)

            self.update_target()
            self.epsilon = max(0.1, self.decay * self.epsilon)
            ep_end = time.time()
            self.ep_time.append(ep_end - ep_start)
            
            cumulative_end = time.time()
            self.cumulative_time.append(cumulative_end - cumulative_start)
            
            if episode % 10 == 0:
                print(f'Episode {episode}: {total}')
            
            if (episode % 100 == 0) or episode == 1:
                self.qnetwork.save(('Saved Networks/ddqn_model_{0}'.format(count)))
                txt.write("Save {0} - Episode {1}, Reward: {2}, Average Reward: {3}\n".format(count, 
                                                                                          episode, 
                                                                                          total, 
                                                                                          np.mean(average)))
                count += 1

        self.rewards = rewards
        self.average_reward = average_reward
        
    def test_model(self, env, num_episodes, file):
        self.qnetwork = tf.keras.models.load_model(file)
        self.epsilon = 0
        
        count = 0
        rewards, average_reward, all_eps_frames = [], [], []
        average = deque(maxlen=100)
        eps_frames = None
        
        for episode in range(1, num_episodes + 1):
            state = env.reset()
            total = 0
            eps_frames = []
            terminal = False
            
            while not terminal:
                action = self.policy(state)
                next_state, reward, terminal, _ = env.step(action)
                
                eps_frames.append(env.render(mode='rgb_array'))
                
                total += reward                
                state = next_state
                
                if terminal:
                    all_eps_frames.append(eps_frames)
            
            average.append(total)
            average_reward.append(np.mean(average))
            rewards.append(total)
            print(f'Episode {episode}: {total}')

        self.rewards = rewards
        self.average_reward = average_reward

        return all_eps_frames
        
    def plot_results(self):
        plt.figure(figsize = (10, 6), dpi = 100)

        plt.plot(self.rewards, alpha = 0.7, label = 'Rewards')
        plt.plot(self.average_reward, 'red', label = 'Average Rewards')
        plt.axhline(y = 200, color = 'orange', linestyle = '-', label = 'Threshold')
        
        plt.xlim(0, len(self.rewards))
        plt.title('Learning Curve', fontweight = 'bold')
        plt.xlabel('Episode', fontweight = 'bold')
        plt.ylabel('Reward', fontweight = 'bold')
        plt.legend(loc = 'lower right')

# %%
env = gym.make("LunarLander-v2")
optimizer = Adam(learning_rate = 0.0001)
agent = DDQNAgent(env, optimizer, batch_size = 64)

# %%
start = time.time()
agent.train_model(env, num_episodes = num_episodes)
end = time.time()
print('Time Taken to Train: ', end-start)
# Out:
# C:\Users\johng\anaconda3\lib\site-packages\keras\engine\training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Episode 10: -124.34101810074691
# Episode 20: -106.01583522672047
# Episode 30: -109.31120127257475
# Episode 40: -275.6851452665964
# Episode 50: -122.26026510464611
# Episode 60: -170.65730155192773
# Episode 70: -113.41929931051745
# Episode 80: -161.90863941822167
# Episode 90: -23.538405028792127
# Episode 100: 20.29500072487332
# Episode 110: -57.434858455710575
# Episode 120: -22.098460423053282
# Episode 130: -86.87418210502096
# Episode 140: -34.23153161544272
# Episode 150: -265.9122733463216
# Episode 160: -388.62416557507595
# Episode 170: -301.73538365052246
# Episode 180: -152.9081121033381
# Episode 190: -9.969588100025549
# Episode 200: -73.92038273066882
# Episode 210: -51.25397496237032
# Episode 220: -89.23232211867744
# Episode 230: -4.285659725565933
# Episode 240: -47.21719974580287
# Episode 250: -39.50958467729491
# Episode 260: -363.21281744794584
# Episode 270: -21.534362430226953
# Episode 280: 16.719673501936544
# Episode 290: 11.889701173295624
# Episode 300: 5.6663894591341535
# Episode 310: -58.594280656163086
# Episode 320: -11.554917612469875
# Episode 330: -22.51854142670314
# Episode 340: 64.98129929561797
# Episode 350: 136.76413985801298
# Episode 360: -95.59417027788388
# Episode 370: 9.801827662959617
# Episode 380: 213.07983682115133
# Episode 390: 228.37040921195586
# Episode 400: 263.79674934733964
# Episode 410: 204.57111101000606
# Episode 420: 232.98768956124334
# Episode 430: 236.08608247778326
# Episode 440: 276.9648117583031
# Episode 450: 243.65246125377297
# Episode 460: 225.19651710417975
# Episode 470: 290.30407588303103
# Episode 480: 263.40741857015905
# Episode 490: 267.1920071813779
# Episode 500: 244.5725481025686
# Episode 510: 237.11989642017852
# Episode 520: 192.36498709686308
# Episode 530: 240.8551719106597
# Episode 540: 298.0890250891761
# Episode 550: 189.38006138337647
# Episode 560: 189.2373502927798
# Episode 570: 277.7974421543337
# Episode 580: 260.3549883903977
# Episode 590: 251.73096766506444
# Episode 600: 217.41869866150705
# Episode 610: 248.16117976140583
# Episode 620: 261.2351084506443
# Episode 630: 225.74675771457254
# Episode 640: 286.4404768297719
# Episode 650: 252.01055732153782
# Episode 660: 283.8292017631171
# Episode 670: 231.9135738241295
# Episode 680: 265.56652251913425
# Episode 690: 269.97267245129694
# Episode 700: 248.74558013482866
# Episode 710: 252.56883990778428
# Episode 720: 227.74283499874548
# Episode 730: 208.1637640758724
# Episode 740: 230.53148373646982
# Episode 750: 302.2755759848619
# Episode 760: 218.19933837760445
# Episode 770: 256.71737967060193
# Episode 780: 245.00221363222485
# Episode 790: 202.56824370438642
# Episode 800: 258.1073372150505
# Episode 810: 284.7946940383513
# Episode 820: 252.38945233317287
# Episode 830: 291.43654885737277
# Episode 840: 293.96081220977425
# Episode 850: 253.3338290576856
# Episode 860: 244.68302708480113
# Episode 870: 283.8100217483948
# Episode 880: 260.7354320545983
# Episode 890: 275.96905190406744
# Episode 900: 232.54759403879117
# Episode 910: 252.04174842051873
# Episode 920: 252.7926819723894
# Episode 930: 247.85442868178308
# Episode 940: 273.73566455669123
# Episode 950: 226.36452498396753
# Episode 960: 275.73483140054446
# Episode 970: 186.56549611939454
# Episode 980: 298.1070812692837
# Episode 990: 287.87761033901893
# Episode 1000: 286.12900608711294
# Episode 1010: 257.98997856680114
# Episode 1020: 207.2837718980456
# Episode 1030: 249.49263620345644
# Episode 1040: 289.2185684547979
# Episode 1050: 294.0223457556599
# Episode 1060: 241.59510328022174
# Episode 1070: 253.24376194681128
# Episode 1080: 233.42346229723933
# Episode 1090: 251.3494041829256
# Episode 1100: 270.8585051536154
# Episode 1110: 287.4285263769226
# Episode 1120: 235.56546837759294
# Episode 1130: 289.41309112632825
# Episode 1140: 294.30041536394805
# Episode 1150: 257.4437296726751
# Episode 1160: 283.57395584667506
# Episode 1170: 238.39777109684775
# Episode 1180: 22.641193900560168
# Episode 1190: 283.76293312609863
# Episode 1200: 271.11111831275
# Episode 1210: 292.5308531849863
# Episode 1220: 301.89913859432977
# Episode 1230: 261.55331971919827
# Episode 1240: 275.88811749728006
# Episode 1250: 294.7254928642644
# Episode 1260: 267.87450895268796
# Episode 1270: 291.3179553252535
# Episode 1280: 273.23806921480787
# Episode 1290: 271.84570187380734
# Episode 1300: 251.25760242307584
# Episode 1310: 273.329463785071
# Episode 1320: 257.45897192235896
# Episode 1330: 269.3450947574565
# Episode 1340: 290.238673172925
# Episode 1350: 302.6751704226489
# Episode 1360: 180.93707962947212
# Episode 1370: 240.74944025408513
# Episode 1380: 276.262522225892
# Episode 1390: 239.57580597156843
# Episode 1400: 303.4193331658395
# Episode 1410: 251.06954154294567
# Episode 1420: 246.61396807876466
# Episode 1430: 256.9421311673508
# Episode 1440: 293.66272987196874
# Episode 1450: 263.98873818189725
# Episode 1460: 277.399625097874
# Episode 1470: 255.30234741766705
# Episode 1480: 295.7059931052811
# Episode 1490: 274.49074264231683
# Episode 1500: 269.75724888488025
# Episode 1510: 243.88355706069873
# Episode 1520: 269.18735207806327
# Episode 1530: 249.60081463973725
# Episode 1540: 254.88611112106076
# Episode 1550: 286.3561739186583
# Episode 1560: 245.6489150875679
# Episode 1570: 239.67740243170715
# Episode 1580: 293.079631950333
# Episode 1590: 282.2836335820805
# Episode 1600: 142.69016417033708
# Episode 1610: 233.1385833918815
# Episode 1620: 300.5922793336226
# Episode 1630: 280.15396709814445
# Episode 1640: 230.0234640378109
# Episode 1650: 106.15937825681742
# Episode 1660: 229.49001377487875
# Episode 1670: 260.43387056108645
# Episode 1680: 268.86242905711276
# Episode 1690: 249.24622365096653
# Episode 1700: 278.5168307812206
# Episode 1710: 262.77020094514575
# Episode 1720: 303.5204091320081
# Episode 1730: 232.22047876316898
# Episode 1740: 291.86576450514633
# Episode 1750: 260.6763031587724
# Episode 1760: 261.05077595341936
# Episode 1770: -156.61223005535345
# Episode 1780: 291.8149121817862
# Episode 1790: 269.8034945078381
# Episode 1800: 282.35849689521524
# Episode 1810: 296.47406685203566
# Episode 1820: 256.65386263761815
# Episode 1830: 276.1420143628024
# Episode 1840: 296.43774624254763
# Episode 1850: 299.98422478107915
# Episode 1860: 282.15025489265895
# Episode 1870: 246.68645581012234
# Episode 1880: 266.99502452513707
# Episode 1890: 293.2977762798573
# Episode 1900: 270.9595585265696
# Episode 1910: 279.3216690416271
# Episode 1920: 251.27840575631407
# Episode 1930: 273.9042832156005
# Episode 1940: 259.87073584674465
# Episode 1950: 233.2892211743038
# Episode 1960: 291.5469246505131
# Episode 1970: 277.47821484887083
# Episode 1980: 235.34189801388374
# Episode 1990: 241.5822555800124
# Episode 2000: 227.8075658877329
# Time Taken to Train:  4352.3304080963135

# %% [markdown]
# ## Storing Rewards per Episode in DataFrame and Saving as CSV File

# %%
'''RUN CELL AND UNCOMMENT LAST LINE IF MODEL HAS BEEN TRAINED, OTHERWISE IGNORE'''
df = pd.DataFrame()
df['Reward'] = agent.rewards
df['Average Reward'] = agent.average_reward
df['Time'] = agent.ep_time
df['Cumulative Time'] = agent.cumulative_time
df.to_csv('DDQN Rewards.csv')

# %% [markdown]
# ## Reloading Instance with Saved Rewards and Plotting Train Results

# %%
df = pd.read_csv('DDQN Rewards.csv')
env = gym.make("LunarLander-v2")
optimizer = Adam(learning_rate = 0.0001)

agent_plt = DDQNAgent(env, optimizer, batch_size = 64)
agent_plt.rewards = df['Reward']
agent_plt.average_reward = df['Average Reward']
agent_plt.plot_results()

# %% [markdown]
# ## Testing Models and Recording Performance at Varying Number of Episodes Trained

# %%
env = gym.make("LunarLander-v2")
optimizer = Adam(learning_rate = 0.0001)


episodes_ddqn = []

agent_test = DDQNAgent(env, optimizer, batch_size = 64)
print('2000 Episodes Trained')
test = agent_test.test_model(env, 3, 'Saved Networks/ddqn_model_3')

episodes_clip = []
for i in range(3):
    episodes_clip += test[i]
episodes_ddqn.append(episodes_clip)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/mk/6dqc1l9n1hd216kbwtlcskyw0000gn/T/ipykernel_62418/4061482058.py in <module>
#       5 episodes_ddqn = []
#       6
# ----> 7 agent_test = DDQNAgent(env, optimizer, batch_size = 64)
#       8 print('2000 Episodes Trained')
#       9 test = agent_test.test_model(env, 3, 'Saved Networks/ddqn_model_3')
#
# NameError: name 'DDQNAgent' is not defined

# %%
env.close()

# %%
# save_video(episodes_ddqn, 'DDQN', env)

# %% [markdown]
# ## Implementing PPO(Proximal Policy Optimization) Algorithm with Experience Replay

# %%
class PPO_Buffer:
    def __init__(self, batch_size):
        self.states = []
        self.actions = []
        self.logprobs = []
        self.values = []
        self.rewards = []
        self.dones = []  # terminal flags
        self.batch_size = batch_size

    def pick_batch(self):
        n_states = len(self.states)
        batch_start = np.arange(0, n_states, self.batch_size)
        indices = np.arange(n_states, dtype=np.int64)
        np.random.shuffle(indices)
        batches = [indices[i: i+self.batch_size] for i in batch_start]

        return np.array(self.states), np.array(self.actions), np.array(self.logprobs), \
                  np.array(self.values), np.array(self.rewards), np.array(self.dones), batches

    def save_buffer(self, state, action, logprob, value, reward, done):
        self.states.append(state)
        self.actions.append(action)
        self.logprobs.append(logprob)
        self.values.append(value)
        self.rewards.append(reward)
        self.dones.append(done)

    def clear_buffer(self):
        self.states.clear()
        self.actions.clear()
        self.logprobs.clear()
        self.values.clear()
        self.rewards.clear()
        self.dones.clear()

# %%
class ActorNetwork(nn.Module):
    def __init__(self, n_actions, input_d, alpha, fc1_d=256, fc2_d=256, fc3_d=128):
        super(ActorNetwork, self).__init__()

        self.actor = nn.Sequential(
            nn.Linear(*input_d, fc1_d),
            nn.ReLU(),
            nn.Linear(fc1_d, fc2_d),
            nn.ReLU(),
            nn.Linear(fc2_d, fc3_d),
            nn.ReLU(),
            nn.Linear(fc3_d, n_actions),
            nn.Softmax(dim=-1),
        )
        self.optimizer = optim.Adam(self.parameters(), lr=alpha)

    def forward(self, state):
        return Categorical(self.actor(state))


class CriticNetwork(nn.Module):
    def __init__(self, input_d, alpha, fc1_d=256, fc2_d=256, fc3_d=128):
        super(CriticNetwork, self).__init__()
        self.critic = nn.Sequential(
            nn.Linear(*input_d, fc1_d),
            nn.ReLU(),
            nn.Linear(fc1_d, fc2_d),
            nn.ReLU(),
            nn.Linear(fc2_d, fc3_d),
            nn.ReLU(),
            nn.Linear(fc3_d, 1),
        )
        self.optimizer = optim.Adam(self.parameters(), lr=alpha)

    def forward(self, state):
        return self.critic(state)

# %%
methods = 'ppo'
dir_model = os.getcwd() + '/' + methods + '_model'
dir_video = os.getcwd() + '/' + methods + '_video'

if not os.path.exists(dir_model):
    os.makedirs(dir_model)
if not os.path.exists(dir_video):
    os.makedirs(dir_video)
    
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class Agent:
    def __init__(self, n_actions, input_dims, gamma=0.99, alpha=3e-4, gae=0.95, clip=0.2, batch_size=5, n_epochs=4):
        self.gamma = gamma
        self.clip = clip
        self.n_epochs = n_epochs
        self.gae = gae

        self.buffer = PPO_Buffer(batch_size)
        self.actor = ActorNetwork(n_actions, input_dims, alpha)
        self.critic = CriticNetwork(input_dims, alpha)


    def choose_action(self, observation):
        state = torch.tensor(np.array([observation]), dtype=torch.float).to(device)
        # give distribution from neural network for choosing an action
        dist = self.actor(state)
        value = self.critic(state)
        action = dist.sample()

        prob = torch.squeeze(dist.log_prob(action)).item()
        action = torch.squeeze(action).item()
        value = torch.squeeze(value).item()

        return action, prob, value

    def learn(self):
        for _ in range(self.n_epochs):
            s, a, old_p, v, r, dones, batches = self.buffer.pick_batch()
            advantage = np.zeros(len(r))

            for t in range(len(r)-1):
                discount = 1
                advantage_t = 0
                for k in range(t, len(r)-1):
                    advantage_t += discount*(r[k] + self.gamma*v[k+1] * (1 - int(dones[k])) - v[k])
                    discount *= self.gamma * self.gae
                advantage[t] = advantage_t
            advantage = torch.tensor(advantage).to(device)
            values = torch.tensor(v).to(device)

            for b in batches:
                states = torch.tensor(s[b], dtype=torch.float).to(device)
                old_probs = torch.tensor(old_p[b]).to(device)
                actions = torch.tensor(a[b]).to(device)

                dist = self.actor(states)
                critic_value = torch.squeeze(self.critic(states))

                new_probs = dist.log_prob(actions)
                weighted_probs = advantage[b] * (new_probs - old_probs).exp()
                weighted_clipped_probs = torch.clamp((new_probs - old_probs).exp(), 1-self.clip, 1+self.clip) * advantage[b]
                actor_loss = - torch.min(weighted_probs, weighted_clipped_probs).mean()
                critic_loss = ((advantage[b] + values[b] - critic_value) ** 2).mean()
                total_loss = actor_loss + critic_loss/2

                self.actor.optimizer.zero_grad()
                self.critic.optimizer.zero_grad()
                total_loss.backward()
                self.actor.optimizer.step()
                self.critic.optimizer.step()

        self.buffer.clear_buffer()

    def save_models(self, ep):
        print('Saving...')
        torch.save(self.actor.state_dict(), 'ppo_model/actor_ppo_{}.h5'.format(ep))
        torch.save(self.critic.state_dict(), 'ppo_model/critic_ppo_{}.h5'.format(ep))

    def load_models(self, ep):
        print('Loading...')
        self.actor.load_state_dict(torch.load('ppo_model/actor_ppo_{}.h5'.format(ep)))
        self.critic.load_state_dict(torch.load('ppo_model/critic_ppo_{}.h5'.format(ep)))

# %%
def train_agent(n_episodes):
    start_time = timeit.default_timer()
    n_episodes = n_episodes
    score_history = []
    n_steps = 0
    time_list = []
    
    for i in range(n_episodes):
        observation = env.reset()
        done = False
        score = 0
        start = time.time()
            
        while not done:
            action, prob, value = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            n_steps += 1
            score += reward
            # interface between agent and its memory
            agent.buffer.save_buffer(observation, action, prob, value, reward, done)
            if n_steps % 20 == 0:
                agent.learn()
            observation = observation_
            
            if done:
                end = time.time()
                time_list.append(end - start)
                
        score_history.append(score)
        mean_score = np.mean(score_history[-100:])
        
        if (i+1)%100==0 or i==0:
            agent.save_models(int(i/100+1))

        print('episode{}: score {:.1f}, average score {:.1f}'.format(i, score, mean_score))
    print("--- Training: %s minutes ---" % ((timeit.default_timer() - start_time)/60))

    return score_history, time_list
    
# train to save the model
env = gym.make('LunarLander-v2')
agent = Agent(n_actions=env.action_space.n, input_dims=env.observation_space.shape)
score_history, time_ppo = train_agent(n_episodes=num_episodes)
# Out:
# Saving...
# episode0: score -91.7, average score -91.7
# episode1: score -554.3, average score -323.0
# episode2: score -755.8, average score -467.2
# episode3: score -593.6, average score -498.8
# episode4: score -455.6, average score -490.2
# episode5: score -250.2, average score -450.2
# episode6: score -128.6, average score -404.3
# episode7: score -139.0, average score -371.1
# episode8: score -502.6, average score -385.7
# episode9: score -74.2, average score -354.6
# episode10: score -199.0, average score -340.4
# episode11: score -130.7, average score -322.9
# episode12: score -293.1, average score -320.6
# episode13: score -466.6, average score -331.1
# episode14: score -340.5, average score -331.7
# episode15: score -200.5, average score -323.5
# episode16: score -24.8, average score -305.9
# episode17: score -234.5, average score -302.0
# episode18: score -205.3, average score -296.9
# episode19: score -389.5, average score -301.5
# episode20: score -456.5, average score -308.9
# episode21: score -367.7, average score -311.6
# episode22: score -334.6, average score -312.6
# episode23: score -456.5, average score -318.6
# episode24: score -331.0, average score -319.1
# episode25: score -359.9, average score -320.6
# episode26: score -232.3, average score -317.4
# episode27: score -484.9, average score -323.3
# episode28: score -60.4, average score -314.3
# episode29: score -245.7, average score -312.0
# episode30: score -459.4, average score -316.7
# episode31: score -316.1, average score -316.7
# episode32: score -335.4, average score -317.3
# episode33: score -256.3, average score -315.5
# episode34: score -177.3, average score -311.5
# episode35: score -334.1, average score -312.2
# episode36: score -309.3, average score -312.1
# episode37: score -11.3, average score -304.2
# episode38: score -222.0, average score -302.1
# episode39: score -360.5, average score -303.5
# episode40: score -129.9, average score -299.3
# episode41: score -142.4, average score -295.6
# episode42: score -164.6, average score -292.5
# episode43: score -19.9, average score -286.3
# episode44: score -313.9, average score -286.9
# episode45: score -130.3, average score -283.5
# episode46: score -84.9, average score -279.3
# episode47: score -89.7, average score -275.4
# episode48: score -166.4, average score -273.1
# episode49: score -172.4, average score -271.1
# episode50: score 183.1, average score -262.2
# episode51: score -313.8, average score -263.2
# episode52: score -224.6, average score -262.5
# episode53: score -90.9, average score -259.3
# episode54: score -167.1, average score -257.6
# episode55: score -12.9, average score -253.2
# episode56: score -282.2, average score -253.8
# episode57: score -247.3, average score -253.6
# episode58: score -73.2, average score -250.6
# episode59: score -36.2, average score -247.0
# episode60: score -106.1, average score -244.7
# episode61: score -27.7, average score -241.2
# episode62: score -120.4, average score -239.3
# episode63: score -20.1, average score -235.9
# episode64: score -34.3, average score -232.8
# episode65: score 19.4, average score -228.9
# episode66: score -65.8, average score -226.5
# episode67: score 1.7, average score -223.1
# episode68: score -121.0, average score -221.7
# episode69: score -47.3, average score -219.2
# episode70: score -107.2, average score -217.6
# episode71: score -72.8, average score -215.6
# episode72: score -111.4, average score -214.2
# episode73: score -94.4, average score -212.5
# episode74: score -107.9, average score -211.1
# episode75: score -65.0, average score -209.2
# episode76: score -443.6, average score -212.3
# episode77: score -76.5, average score -210.5
# episode78: score -204.0, average score -210.4
# episode79: score -76.4, average score -208.8
# episode80: score -55.5, average score -206.9
# episode81: score -95.3, average score -205.5
# episode82: score -110.3, average score -204.4
# episode83: score -124.9, average score -203.4
# episode84: score -78.5, average score -202.0
# episode85: score -84.2, average score -200.6
# episode86: score -61.8, average score -199.0
# episode87: score -80.1, average score -197.6
# episode88: score -123.6, average score -196.8
# episode89: score -88.1, average score -195.6
# episode90: score -132.1, average score -194.9
# episode91: score -135.7, average score -194.3
# episode92: score -95.8, average score -193.2
# episode93: score -52.3, average score -191.7
# episode94: score -86.9, average score -190.6
# episode95: score -124.9, average score -189.9
# episode96: score -112.3, average score -189.1
# episode97: score -33.0, average score -187.5
# episode98: score -60.4, average score -186.2
# Saving...
# episode99: score -84.8, average score -185.2
# episode100: score -36.5, average score -184.7
# episode101: score -141.2, average score -180.5
# episode102: score -80.8, average score -173.8
# episode103: score -122.1, average score -169.1
# episode104: score -88.7, average score -165.4
# episode105: score -20.1, average score -163.1
# episode106: score -61.1, average score -162.4
# episode107: score 16.1, average score -160.9
# episode108: score -34.0, average score -156.2
# episode109: score 10.0, average score -155.3
# episode110: score 153.4, average score -151.8
# episode111: score 125.4, average score -149.3
# episode112: score -91.3, average score -147.2
# episode113: score 8.7, average score -142.5
# episode114: score 17.2, average score -138.9
# episode115: score 18.7, average score -136.7
# episode116: score 38.9, average score -136.1
# episode117: score 35.1, average score -133.4
# episode118: score -68.9, average score -132.0
# episode119: score -61.1, average score -128.7
# episode120: score -99.0, average score -125.2
# episode121: score -29.5, average score -121.8
# episode122: score -2.2, average score -118.5
# episode123: score -44.3, average score -114.3
# episode124: score -30.3, average score -111.3
# episode125: score -35.7, average score -108.1
# episode126: score -101.0, average score -106.8
# episode127: score -37.7, average score -102.3
# episode128: score 3.4, average score -101.7
# episode129: score 3.7, average score -99.2
# episode130: score -30.5, average score -94.9
# episode131: score -10.1, average score -91.8
# episode132: score -70.9, average score -89.2
# episode133: score -90.1, average score -87.5
# episode134: score -69.3, average score -86.4
# episode135: score -160.3, average score -84.7
# episode136: score -135.7, average score -83.0
# episode137: score -148.2, average score -84.3
# episode138: score -179.9, average score -83.9
# episode139: score -154.6, average score -81.9
# episode140: score -156.7, average score -82.1
# episode141: score -112.2, average score -81.8
# episode142: score -127.3, average score -81.4
# episode143: score -119.8, average score -82.4
# episode144: score -110.6, average score -80.4
# episode145: score -113.5, average score -80.2
# episode146: score -90.7, average score -80.3
# episode147: score -131.8, average score -80.7
# episode148: score -71.7, average score -79.8
# episode149: score -159.4, average score -79.6
# episode150: score -88.6, average score -82.4
# episode151: score 149.0, average score -77.7
# episode152: score -119.6, average score -76.7
# episode153: score -349.7, average score -79.3
# episode154: score -109.4, average score -78.7
# episode155: score -189.2, average score -80.5
# episode156: score 89.5, average score -76.7
# episode157: score -80.5, average score -75.1
# episode158: score -151.1, average score -75.9
# episode159: score -156.0, average score -77.1
# episode160: score -107.5, average score -77.1
# episode161: score -78.6, average score -77.6
# episode162: score -97.7, average score -77.3
# episode163: score -138.7, average score -78.5
# episode164: score -67.0, average score -78.9
# episode165: score -57.0, average score -79.6
# episode166: score -101.6, average score -80.0
# episode167: score -74.0, average score -80.7
# episode168: score -148.0, average score -81.0
# episode169: score -109.2, average score -81.6
# episode170: score -72.1, average score -81.3
# episode171: score -121.9, average score -81.8
# episode172: score -65.2, average score -81.3
# episode173: score -115.4, average score -81.5
# episode174: score -30.7, average score -80.7
# episode175: score -130.0, average score -81.4
# episode176: score -7.7, average score -77.0
# episode177: score 104.5, average score -75.2
# episode178: score 43.0, average score -72.8
# episode179: score 49.8, average score -71.5
# episode180: score -108.5, average score -72.0
# episode181: score 1.8, average score -71.1
# episode182: score -23.4, average score -70.2
# episode183: score -33.8, average score -69.3
# episode184: score 125.5, average score -67.2
# episode185: score 97.8, average score -65.4
# episode186: score -115.7, average score -66.0
# episode187: score 100.3, average score -64.1
# episode188: score 188.1, average score -61.0
# episode189: score -69.0, average score -60.8
# episode190: score 140.2, average score -58.1
# episode191: score 173.2, average score -55.0
# episode192: score -117.4, average score -55.2
# episode193: score -60.1, average score -55.3
# episode194: score 123.8, average score -53.2
# episode195: score -33.8, average score -52.3
# episode196: score -35.6, average score -51.5
# episode197: score 177.2, average score -49.4
# episode198: score 145.7, average score -47.4
# Saving...
# episode199: score -78.1, average score -47.3
# episode200: score -15.3, average score -47.1
# episode201: score -118.6, average score -46.9
# episode202: score -65.2, average score -46.7
# episode203: score -68.9, average score -46.2
# episode204: score 9.6, average score -45.2
# episode205: score 69.0, average score -44.3
# episode206: score 53.6, average score -43.2
# episode207: score 181.6, average score -41.5
# episode208: score -82.9, average score -42.0
# episode209: score 202.9, average score -40.1
# episode210: score 55.1, average score -41.0
# episode211: score 98.2, average score -41.3
# episode212: score 161.8, average score -38.8
# episode213: score 151.8, average score -37.4
# episode214: score -84.1, average score -38.4
# episode215: score 198.9, average score -36.6
# episode216: score 74.8, average score -36.2
# episode217: score 277.9, average score -33.8
# episode218: score -26.7, average score -33.4
# episode219: score 49.6, average score -32.3
# episode220: score -13.9, average score -31.4
# episode221: score -44.5, average score -31.6
# episode222: score 203.9, average score -29.5
# episode223: score 19.3, average score -28.9
# episode224: score 192.0, average score -26.6
# episode225: score 47.3, average score -25.8
# episode226: score -76.4, average score -25.6
# episode227: score -137.9, average score -26.6
# episode228: score -83.2, average score -27.4
# episode229: score -46.1, average score -27.9
# episode230: score -49.7, average score -28.1
# episode231: score -26.0, average score -28.3
# episode232: score -92.4, average score -28.5
# episode233: score 3.8, average score -27.5
# episode234: score 100.7, average score -25.8
# episode235: score -96.8, average score -25.2
# episode236: score -53.3, average score -24.4
# episode237: score -43.5, average score -23.3
# episode238: score 22.5, average score -21.3
# episode239: score -13.3, average score -19.9
# episode240: score -71.3, average score -19.1
# episode241: score -65.3, average score -18.6
# episode242: score 126.7, average score -16.0
# episode243: score 191.0, average score -12.9
# episode244: score 182.2, average score -10.0
# episode245: score 206.3, average score -6.8
# episode246: score 7.7, average score -5.8
# episode247: score -90.6, average score -5.4
# episode248: score 164.2, average score -3.1
# episode249: score 26.9, average score -1.2
# episode250: score -43.5, average score -0.7
# episode251: score 45.6, average score -1.8
# episode252: score 261.7, average score 2.0
# episode253: score 162.3, average score 7.2
# episode254: score 190.5, average score 10.2
# episode255: score 212.9, average score 14.2
# episode256: score 194.7, average score 15.2
# episode257: score -87.9, average score 15.2
# episode258: score -10.5, average score 16.6
# episode259: score -60.9, average score 17.5
# episode260: score 100.4, average score 19.6
# episode261: score 68.7, average score 21.1
# episode262: score 184.9, average score 23.9
# episode263: score 172.4, average score 27.0
# episode264: score -5.8, average score 27.6
# episode265: score -90.1, average score 27.3
# episode266: score 164.6, average score 30.0
# episode267: score 122.2, average score 31.9
# episode268: score 224.0, average score 35.6
# episode269: score -41.4, average score 36.3
# episode270: score 237.6, average score 39.4
# episode271: score 242.5, average score 43.1
# episode272: score -99.8, average score 42.7
# episode273: score 138.0, average score 45.2
# episode274: score 40.3, average score 46.0
# episode275: score 1.7, average score 47.3
# episode276: score -56.0, average score 46.8
# episode277: score -81.9, average score 44.9
# episode278: score -37.3, average score 44.1
# episode279: score -92.6, average score 42.7
# episode280: score -24.5, average score 43.5
# episode281: score 190.5, average score 45.4
# episode282: score 194.9, average score 47.6
# episode283: score 208.8, average score 50.0
# episode284: score 167.7, average score 50.5
# episode285: score 155.7, average score 51.0
# episode286: score 188.9, average score 54.1
# episode287: score -76.2, average score 52.3
# episode288: score 177.0, average score 52.2
# episode289: score -104.1, average score 51.9
# episode290: score 156.5, average score 52.0
# episode291: score 20.6, average score 50.5
# episode292: score 161.1, average score 53.3
# episode293: score 135.6, average score 55.2
# episode294: score 75.7, average score 54.7
# episode295: score 153.1, average score 56.6
# episode296: score -73.2, average score 56.2
# episode297: score 150.7, average score 56.0
# episode298: score 163.5, average score 56.2
# Saving...
# episode299: score -162.9, average score 55.3
# episode300: score -96.2, average score 54.5
# episode301: score 100.6, average score 56.7
# episode302: score 151.2, average score 58.9
# episode303: score 186.7, average score 61.4
# episode304: score 170.7, average score 63.0
# episode305: score 134.3, average score 63.7
# episode306: score -130.1, average score 61.8
# episode307: score -95.9, average score 59.1
# episode308: score -157.1, average score 58.3
# episode309: score -119.2, average score 55.1
# episode310: score -94.5, average score 53.6
# episode311: score -110.1, average score 51.5
# episode312: score -143.2, average score 48.5
# episode313: score -65.6, average score 46.3
# episode314: score 166.1, average score 48.8
# episode315: score -17.8, average score 46.6
# episode316: score -32.2, average score 45.6
# episode317: score 126.7, average score 44.0
# episode318: score 122.9, average score 45.5
# episode319: score 155.6, average score 46.6
# episode320: score 116.1, average score 47.9
# episode321: score 41.5, average score 48.8
# episode322: score 195.8, average score 48.7
# episode323: score -158.0, average score 46.9
# episode324: score -189.6, average score 43.1
# episode325: score -1.5, average score 42.6
# episode326: score -143.8, average score 41.9
# episode327: score 177.3, average score 45.1
# episode328: score -127.9, average score 44.6
# episode329: score -71.4, average score 44.4
# episode330: score -117.2, average score 43.7
# episode331: score 217.9, average score 46.1
# episode332: score 138.2, average score 48.5
# episode333: score -62.0, average score 47.8
# episode334: score -158.6, average score 45.2
# episode335: score 143.0, average score 47.6
# episode336: score -0.8, average score 48.1
# episode337: score 144.7, average score 50.0
# episode338: score 155.0, average score 51.3
# episode339: score 180.4, average score 53.3
# episode340: score 205.0, average score 56.0
# episode341: score 251.5, average score 59.2
# episode342: score -59.2, average score 57.3
# episode343: score -80.1, average score 54.6
# episode344: score -164.8, average score 51.2
# episode345: score -100.1, average score 48.1
# episode346: score -44.5, average score 47.6
# episode347: score -35.9, average score 48.1
# episode348: score -43.5, average score 46.0
# episode349: score -66.8, average score 45.1
# episode350: score -54.5, average score 45.0
# episode351: score -52.9, average score 44.0
# episode352: score -45.7, average score 40.9
# episode353: score -52.4, average score 38.8
# episode354: score -16.1, average score 36.7
# episode355: score -176.1, average score 32.8
# episode356: score -113.8, average score 29.7
# episode357: score -87.9, average score 29.7
# episode358: score -130.1, average score 28.5
# episode359: score -111.3, average score 28.0
# episode360: score -193.7, average score 25.1
# episode361: score -69.7, average score 23.7
# episode362: score -10.7, average score 21.8
# episode363: score -22.0, average score 19.8
# episode364: score -1.8, average score 19.9
# episode365: score 62.7, average score 21.4
# episode366: score 182.1, average score 21.6
# episode367: score 53.5, average score 20.9
# episode368: score 184.2, average score 20.5
# episode369: score 142.3, average score 22.3
# episode370: score -95.4, average score 19.0
# episode371: score 250.2, average score 19.1
# episode372: score 170.9, average score 21.8
# episode373: score 229.1, average score 22.7
# episode374: score -20.0, average score 22.1
# episode375: score 192.0, average score 24.0
# episode376: score 195.3, average score 26.5
# episode377: score 11.8, average score 27.4
# episode378: score 102.6, average score 28.8
# episode379: score 98.0, average score 30.7
# episode380: score 200.6, average score 33.0
# episode381: score -107.3, average score 30.0
# episode382: score 28.3, average score 28.3
# episode383: score -82.6, average score 25.4
# episode384: score -56.2, average score 23.2
# episode385: score 123.2, average score 22.9
# episode386: score -87.1, average score 20.1
# episode387: score -73.4, average score 20.1
# episode388: score 121.7, average score 19.6
# episode389: score -21.5, average score 20.4
# episode390: score -28.9, average score 18.5
# episode391: score 281.1, average score 21.2
# episode392: score -99.7, average score 18.5
# episode393: score -17.5, average score 17.0
# episode394: score 276.8, average score 19.0
# episode395: score 239.9, average score 19.9
# episode396: score -85.8, average score 19.8
# episode397: score 180.6, average score 20.1
# episode398: score 198.7, average score 20.4
# Saving...
# episode399: score 177.5, average score 23.8
# episode400: score -4.6, average score 24.7
# episode401: score -27.3, average score 23.5
# episode402: score 167.6, average score 23.6
# episode403: score -77.7, average score 21.0
# episode404: score -107.4, average score 18.2
# episode405: score 181.8, average score 18.7
# episode406: score -132.3, average score 18.7
# episode407: score 172.4, average score 21.3
# episode408: score -188.6, average score 21.0
# episode409: score -106.1, average score 21.2
# episode410: score 221.1, average score 24.3
# episode411: score -68.2, average score 24.7
# episode412: score -143.5, average score 24.7
# episode413: score 184.6, average score 27.2
# episode414: score 233.3, average score 27.9
# episode415: score -2.7, average score 28.1
# episode416: score -53.4, average score 27.8
# episode417: score 204.8, average score 28.6
# episode418: score -17.1, average score 27.2
# episode419: score 213.5, average score 27.8
# episode420: score -89.6, average score 25.7
# episode421: score -16.5, average score 25.2
# episode422: score 230.4, average score 25.5
# episode423: score 193.3, average score 29.0
# episode424: score 212.7, average score 33.0
# episode425: score 223.3, average score 35.3
# episode426: score 166.5, average score 38.4
# episode427: score 243.2, average score 39.1
# episode428: score 208.9, average score 42.4
# episode429: score -30.7, average score 42.8
# episode430: score 166.1, average score 45.7
# episode431: score -51.8, average score 43.0
# episode432: score 225.7, average score 43.8
# episode433: score 190.3, average score 46.4
# episode434: score 217.9, average score 50.1
# episode435: score 139.6, average score 50.1
# episode436: score 209.6, average score 52.2
# episode437: score 108.6, average score 51.8
# episode438: score 147.0, average score 51.8
# episode439: score 187.2, average score 51.8
# episode440: score 221.7, average score 52.0
# episode441: score 92.7, average score 50.4
# episode442: score 106.5, average score 52.1
# episode443: score 74.2, average score 53.6
# episode444: score 70.8, average score 56.0
# episode445: score 192.6, average score 58.9
# episode446: score 226.2, average score 61.6
# episode447: score -8.9, average score 61.9
# episode448: score 21.2, average score 62.5
# episode449: score 132.6, average score 64.5
# episode450: score 153.5, average score 66.6
# episode451: score 163.8, average score 68.8
# episode452: score 177.0, average score 71.0
# episode453: score 105.0, average score 72.6
# episode454: score -105.9, average score 71.7
# episode455: score -102.3, average score 72.4
# episode456: score -93.0, average score 72.6
# episode457: score -131.1, average score 72.2
# episode458: score -114.7, average score 72.3
# episode459: score -86.4, average score 72.6
# episode460: score -133.2, average score 73.2
# episode461: score -129.7, average score 72.6
# episode462: score -166.2, average score 71.0
# episode463: score -86.1, average score 70.4
# episode464: score -186.1, average score 68.5
# episode465: score 167.8, average score 69.6
# episode466: score 132.8, average score 69.1
# episode467: score -234.4, average score 66.2
# episode468: score -68.4, average score 63.7
# episode469: score -49.2, average score 61.8
# episode470: score -36.0, average score 62.4
# episode471: score -86.5, average score 59.0
# episode472: score -67.4, average score 56.6
# episode473: score -17.9, average score 54.2
# episode474: score -10.1, average score 54.3
# episode475: score -51.0, average score 51.8
# episode476: score 9.6, average score 50.0
# episode477: score 57.8, average score 50.4
# episode478: score 95.0, average score 50.3
# episode479: score 187.8, average score 51.2
# episode480: score 122.7, average score 50.5
# episode481: score 152.4, average score 53.1
# episode482: score 116.8, average score 53.9
# episode483: score 168.7, average score 56.5
# episode484: score -56.1, average score 56.5
# episode485: score 65.5, average score 55.9
# episode486: score 133.6, average score 58.1
# episode487: score -64.1, average score 58.2
# episode488: score -44.1, average score 56.5
# episode489: score 173.5, average score 58.5
# episode490: score 184.4, average score 60.6
# episode491: score 198.6, average score 59.8
# episode492: score 249.5, average score 63.3
# episode493: score -64.6, average score 62.8
# episode494: score 220.6, average score 62.2
# episode495: score 188.1, average score 61.7
# episode496: score 104.9, average score 63.6
# episode497: score 170.4, average score 63.5
# episode498: score 182.7, average score 63.4
# Saving...
# episode499: score -45.2, average score 61.1
# episode500: score 172.7, average score 62.9
# episode501: score 123.9, average score 64.4
# episode502: score 110.4, average score 63.9
# episode503: score 133.0, average score 66.0
# episode504: score 238.3, average score 69.4
# episode505: score -49.5, average score 67.1
# episode506: score -17.1, average score 68.3
# episode507: score 46.2, average score 67.0
# episode508: score 95.2, average score 69.8
# episode509: score 89.2, average score 71.8
# episode510: score -45.8, average score 69.1
# episode511: score 194.4, average score 71.7
# episode512: score 207.0, average score 75.3
# episode513: score 183.6, average score 75.2
# episode514: score 242.9, average score 75.3
# episode515: score 208.9, average score 77.5
# episode516: score 178.2, average score 79.8
# episode517: score 253.1, average score 80.3
# episode518: score 260.1, average score 83.0
# episode519: score 250.8, average score 83.4
# episode520: score -58.0, average score 83.7
# episode521: score 196.9, average score 85.8
# episode522: score -63.3, average score 82.9
# episode523: score 262.4, average score 83.6
# episode524: score 243.6, average score 83.9
# episode525: score 204.9, average score 83.7
# episode526: score 203.6, average score 84.1
# episode527: score -75.9, average score 80.9
# episode528: score 239.9, average score 81.2
# episode529: score 198.7, average score 83.5
# episode530: score 207.8, average score 83.9
# episode531: score -44.4, average score 84.0
# episode532: score 250.3, average score 84.2
# episode533: score 7.7, average score 82.4
# episode534: score 255.2, average score 82.8
# episode535: score 90.9, average score 82.3
# episode536: score -27.8, average score 79.9
# episode537: score 194.5, average score 80.8
# episode538: score 191.6, average score 81.2
# episode539: score 256.2, average score 81.9
# episode540: score -65.0, average score 79.1
# episode541: score -89.6, average score 77.2
# episode542: score 243.5, average score 78.6
# episode543: score -38.6, average score 77.5
# episode544: score -58.2, average score 76.2
# episode545: score -75.3, average score 73.5
# episode546: score -78.4, average score 70.5
# episode547: score -143.1, average score 69.1
# episode548: score -117.1, average score 67.7
# episode549: score -110.5, average score 65.3
# episode550: score -89.1, average score 62.9
# episode551: score 167.4, average score 62.9
# episode552: score -159.8, average score 59.6
# episode553: score 163.9, average score 60.1
# episode554: score 130.6, average score 62.5
# episode555: score 193.6, average score 65.5
# episode556: score 203.1, average score 68.4
# episode557: score -71.9, average score 69.0
# episode558: score -50.1, average score 69.7
# episode559: score -95.3, average score 69.6
# episode560: score -54.6, average score 70.4
# episode561: score -65.6, average score 71.0
# episode562: score 24.2, average score 72.9
# episode563: score -123.5, average score 72.5
# episode564: score -76.9, average score 73.6
# episode565: score -75.7, average score 71.2
# episode566: score -163.8, average score 68.2
# episode567: score -88.2, average score 69.7
# episode568: score -125.9, average score 69.1
# episode569: score -93.3, average score 68.7
# episode570: score -46.6, average score 68.6
# episode571: score -77.3, average score 68.7
# episode572: score 264.1, average score 72.0
# episode573: score -65.4, average score 71.5
# episode574: score -96.7, average score 70.6
# episode575: score 139.7, average score 72.5
# episode576: score 59.4, average score 73.0
# episode577: score -91.0, average score 71.5
# episode578: score 244.0, average score 73.0
# episode579: score -144.7, average score 69.7
# episode580: score 106.4, average score 69.5
# episode581: score 110.4, average score 69.1
# episode582: score 216.9, average score 70.1
# episode583: score 80.7, average score 69.2
# episode584: score -105.9, average score 68.7
# episode585: score -34.8, average score 67.7
# episode586: score -147.7, average score 64.9
# episode587: score -23.9, average score 65.3
# episode588: score -26.1, average score 65.5
# episode589: score 232.0, average score 66.1
# episode590: score 237.7, average score 66.6
# episode591: score -57.1, average score 64.1
# episode592: score -33.8, average score 61.2
# episode593: score 231.7, average score 64.2
# episode594: score -12.4, average score 61.9
# episode595: score -28.1, average score 59.7
# episode596: score 214.3, average score 60.8
# episode597: score 239.3, average score 61.5
# episode598: score 236.7, average score 62.0
# Saving...
# episode599: score 244.4, average score 64.9
# episode600: score 264.8, average score 65.9
# episode601: score 187.2, average score 66.5
# episode602: score 246.3, average score 67.8
# episode603: score -84.1, average score 65.7
# episode604: score -150.3, average score 61.8
# episode605: score -215.6, average score 60.1
# episode606: score 205.0, average score 62.3
# episode607: score -60.9, average score 61.3
# episode608: score 189.4, average score 62.2
# episode609: score -28.1, average score 61.0
# episode610: score -49.1, average score 61.0
# episode611: score -91.0, average score 58.2
# episode612: score -40.2, average score 55.7
# episode613: score -50.5, average score 53.3
# episode614: score -79.3, average score 50.1
# episode615: score -89.9, average score 47.1
# episode616: score -27.3, average score 45.1
# episode617: score -71.6, average score 41.8
# episode618: score -77.2, average score 38.5
# episode619: score 18.9, average score 36.1
# episode620: score 26.6, average score 37.0
# episode621: score 157.6, average score 36.6
# episode622: score -26.6, average score 37.0
# episode623: score -9.2, average score 34.2
# episode624: score -39.5, average score 31.4
# episode625: score -37.6, average score 29.0
# episode626: score -78.5, average score 26.2
# episode627: score 241.6, average score 29.3
# episode628: score -53.0, average score 26.4
# episode629: score -59.6, average score 23.8
# episode630: score 251.4, average score 24.3
# episode631: score 232.4, average score 27.0
# episode632: score -70.8, average score 23.8
# episode633: score -45.4, average score 23.3
# episode634: score -26.8, average score 20.5
# episode635: score -11.4, average score 19.4
# episode636: score -71.1, average score 19.0
# episode637: score 1.3, average score 17.1
# episode638: score -67.2, average score 14.5
# episode639: score 259.1, average score 14.5
# episode640: score 45.2, average score 15.6
# episode641: score 9.0, average score 16.6
# episode642: score -77.5, average score 13.4
# episode643: score -79.2, average score 13.0
# episode644: score -29.8, average score 13.3
# episode645: score 238.4, average score 16.4
# episode646: score -58.1, average score 16.6
# episode647: score -79.9, average score 17.3
# episode648: score -93.5, average score 17.5
# episode649: score 250.3, average score 21.1
# episode650: score -61.5, average score 21.4
# episode651: score -42.7, average score 19.3
# episode652: score 214.8, average score 23.0
# episode653: score -9.2, average score 21.3
# episode654: score -74.3, average score 19.2
# episode655: score 258.2, average score 19.9
# episode656: score 262.6, average score 20.5
# episode657: score -85.4, average score 20.3
# episode658: score 186.0, average score 22.7
# episode659: score -57.8, average score 23.1
# episode660: score -51.9, average score 23.1
# episode661: score 11.3, average score 23.9
# episode662: score -19.2, average score 23.4
# episode663: score -96.7, average score 23.7
# episode664: score 19.3, average score 24.7
# episode665: score -38.4, average score 25.0
# episode666: score 31.5, average score 27.0
# episode667: score 44.3, average score 28.3
# episode668: score -20.4, average score 29.4
# episode669: score -47.1, average score 29.8
# episode670: score -43.5, average score 29.9
# episode671: score -15.9, average score 30.5
# episode672: score 27.0, average score 28.1
# episode673: score -63.2, average score 28.1
# episode674: score -27.6, average score 28.8
# episode675: score -41.6, average score 27.0
# episode676: score -63.4, average score 25.8
# episode677: score -2.0, average score 26.7
# episode678: score -69.0, average score 23.5
# episode679: score -37.8, average score 24.6
# episode680: score -10.2, average score 23.5
# episode681: score -42.5, average score 21.9
# episode682: score -46.1, average score 19.3
# episode683: score 40.7, average score 18.9
# episode684: score -26.9, average score 19.7
# episode685: score 21.7, average score 20.2
# episode686: score 45.2, average score 22.2
# episode687: score 3.5, average score 22.5
# episode688: score 50.5, average score 23.2
# episode689: score -42.8, average score 20.5
# episode690: score -48.2, average score 17.6
# episode691: score 175.2, average score 19.9
# episode692: score -34.0, average score 19.9
# episode693: score -25.0, average score 17.4
# episode694: score 27.9, average score 17.8
# episode695: score -56.1, average score 17.5
# episode696: score 10.3, average score 15.4
# episode697: score -33.8, average score 12.7
# episode698: score -88.7, average score 9.5
# Saving...
# episode699: score -9.3, average score 6.9
# episode700: score -58.6, average score 3.7
# episode701: score -72.4, average score 1.1
# episode702: score 51.2, average score -0.9
# episode703: score -93.1, average score -0.9
# episode704: score -13.3, average score 0.4
# episode705: score -95.4, average score 1.6
# episode706: score 10.6, average score -0.3
# episode707: score 37.4, average score 0.7
# episode708: score 19.5, average score -1.0
# episode709: score -80.4, average score -1.6
# episode710: score 237.4, average score 1.3
# episode711: score 49.5, average score 2.7
# episode712: score -43.2, average score 2.7
# episode713: score -30.1, average score 2.9
# episode714: score 211.5, average score 5.8
# episode715: score 180.7, average score 8.5
# episode716: score -65.3, average score 8.1
# episode717: score 196.8, average score 10.8
# episode718: score 168.0, average score 13.3
# episode719: score 212.2, average score 15.2
# episode720: score 209.8, average score 17.0
# episode721: score 177.9, average score 17.2
# episode722: score -6.1, average score 17.4
# episode723: score 144.3, average score 19.0
# episode724: score -18.4, average score 19.2
# episode725: score 237.3, average score 21.9
# episode726: score -27.6, average score 22.4
# episode727: score 250.6, average score 22.5
# episode728: score 218.2, average score 25.2
# episode729: score 207.0, average score 27.9
# episode730: score 216.0, average score 27.5
# episode731: score -33.2, average score 24.9
# episode732: score 202.8, average score 27.6
# episode733: score -41.6, average score 27.7
# episode734: score 194.8, average score 29.9
# episode735: score 228.8, average score 32.3
# episode736: score 222.2, average score 35.2
# episode737: score -41.5, average score 34.8
# episode738: score 206.7, average score 37.5
# episode739: score 222.7, average score 37.2
# episode740: score -4.6, average score 36.7
# episode741: score 17.1, average score 36.7
# episode742: score -22.7, average score 37.3
# episode743: score -10.3, average score 38.0
# episode744: score -51.3, average score 37.8
# episode745: score 254.1, average score 37.9
# episode746: score 242.9, average score 40.9
# episode747: score 171.5, average score 43.4
# episode748: score 42.9, average score 44.8
# episode749: score 286.7, average score 45.2
# episode750: score 46.4, average score 46.3
# episode751: score 38.0, average score 47.1
# episode752: score 262.9, average score 47.5
# episode753: score -34.8, average score 47.3
# episode754: score -20.3, average score 47.8
# episode755: score 198.2, average score 47.2
# episode756: score -52.8, average score 44.1
# episode757: score 222.5, average score 47.2
# episode758: score 271.9, average score 48.0
# episode759: score 27.9, average score 48.9
# episode760: score -30.8, average score 49.1
# episode761: score 207.2, average score 51.0
# episode762: score -42.7, average score 50.8
# episode763: score 220.2, average score 54.0
# episode764: score 239.6, average score 56.2
# episode765: score -25.0, average score 56.3
# episode766: score 255.8, average score 58.6
# episode767: score 255.9, average score 60.7
# episode768: score -1.6, average score 60.9
# episode769: score 9.8, average score 61.4
# episode770: score 20.3, average score 62.1
# episode771: score 208.1, average score 64.3
# episode772: score 191.2, average score 65.9
# episode773: score -27.1, average score 66.3
# episode774: score 264.5, average score 69.2
# episode775: score 217.3, average score 71.8
# episode776: score 276.0, average score 75.2
# episode777: score 0.5, average score 75.2
# episode778: score 278.7, average score 78.7
# episode779: score 246.3, average score 81.6
# episode780: score 266.2, average score 84.3
# episode781: score 207.9, average score 86.8
# episode782: score 10.9, average score 87.4
# episode783: score 41.0, average score 87.4
# episode784: score 208.7, average score 89.8
# episode785: score 238.3, average score 91.9
# episode786: score -5.8, average score 91.4
# episode787: score 172.4, average score 93.1
# episode788: score -8.7, average score 92.5
# episode789: score -77.9, average score 92.2
# episode790: score 65.4, average score 93.3
# episode791: score 229.8, average score 93.8
# episode792: score -61.9, average score 93.6
# episode793: score 296.0, average score 96.8
# episode794: score -57.2, average score 95.9
# episode795: score 181.6, average score 98.3
# episode796: score 100.2, average score 99.2
# episode797: score -15.6, average score 99.4
# episode798: score 61.4, average score 100.9
# Saving...
# episode799: score 43.0, average score 101.4
# episode800: score 26.5, average score 102.2
# episode801: score 32.8, average score 103.3
# episode802: score 230.0, average score 105.1
# episode803: score 51.6, average score 106.5
# episode804: score 1.7, average score 106.7
# episode805: score -38.6, average score 107.3
# episode806: score 52.5, average score 107.7
# episode807: score 46.9, average score 107.8
# episode808: score 194.2, average score 109.5
# episode809: score 8.5, average score 110.4
# episode810: score -63.5, average score 107.4
# episode811: score -81.8, average score 106.1
# episode812: score 70.2, average score 107.2
# episode813: score 7.0, average score 107.6
# episode814: score 177.2, average score 107.2
# episode815: score -86.0, average score 104.6
# episode816: score -79.9, average score 104.4
# episode817: score -76.1, average score 101.7
# episode818: score -65.8, average score 99.4
# episode819: score -169.8, average score 95.5
# episode820: score 19.0, average score 93.6
# episode821: score 259.6, average score 94.5
# episode822: score 82.1, average score 95.3
# episode823: score -48.6, average score 93.4
# episode824: score -62.3, average score 93.0
# episode825: score -71.4, average score 89.9
# episode826: score -82.8, average score 89.3
# episode827: score 35.0, average score 87.2
# episode828: score 93.4, average score 85.9
# episode829: score 116.0, average score 85.0
# episode830: score 7.0, average score 82.9
# episode831: score 140.8, average score 84.7
# episode832: score 170.0, average score 84.3
# episode833: score -91.0, average score 83.8
# episode834: score 162.3, average score 83.5
# episode835: score 273.0, average score 84.0
# episode836: score 184.4, average score 83.6
# episode837: score 175.4, average score 85.7
# episode838: score 54.4, average score 84.2
# episode839: score -57.8, average score 81.4
# episode840: score 44.9, average score 81.9
# episode841: score -84.7, average score 80.9
# episode842: score 0.8, average score 81.1
# episode843: score 4.1, average score 81.3
# episode844: score 11.3, average score 81.9
# episode845: score -40.0, average score 79.0
# episode846: score -71.8, average score 75.8
# episode847: score 24.4, average score 74.3
# episode848: score 41.3, average score 74.3
# episode849: score -44.2, average score 71.0
# episode850: score -68.1, average score 69.9
# episode851: score 50.3, average score 70.0
# episode852: score 216.3, average score 69.5
# episode853: score 283.6, average score 72.7
# episode854: score 41.5, average score 73.3
# episode855: score -19.3, average score 71.2
# episode856: score -31.9, average score 71.4
# episode857: score 280.2, average score 71.9
# episode858: score 261.0, average score 71.8
# episode859: score 59.3, average score 72.1
# episode860: score -35.6, average score 72.1
# episode861: score 19.9, average score 70.2
# episode862: score 166.5, average score 72.3
# episode863: score 33.0, average score 70.4
# episode864: score 236.1, average score 70.4
# episode865: score 47.3, average score 71.1
# episode866: score 185.2, average score 70.4
# episode867: score 269.5, average score 70.6
# episode868: score 27.7, average score 70.9
# episode869: score 231.4, average score 73.1
# episode870: score 230.6, average score 75.2
# episode871: score -36.4, average score 72.7
# episode872: score 265.1, average score 73.5
# episode873: score 246.7, average score 76.2
# episode874: score 258.3, average score 76.1
# episode875: score 239.8, average score 76.4
# episode876: score -10.3, average score 73.5
# episode877: score 208.3, average score 75.6
# episode878: score 257.9, average score 75.4
# episode879: score 32.7, average score 73.2
# episode880: score 243.1, average score 73.0
# episode881: score -31.3, average score 70.6
# episode882: score 17.1, average score 70.7
# episode883: score 18.9, average score 70.5
# episode884: score 20.1, average score 68.6
# episode885: score -43.4, average score 65.8
# episode886: score 18.3, average score 66.0
# episode887: score 269.9, average score 67.0
# episode888: score 13.7, average score 67.2
# episode889: score 228.7, average score 70.3
# episode890: score -53.5, average score 69.1
# episode891: score 184.2, average score 68.6
# episode892: score 265.6, average score 71.9
# episode893: score 201.0, average score 70.9
# episode894: score 44.0, average score 72.0
# episode895: score 27.4, average score 70.4
# episode896: score -43.3, average score 69.0
# episode897: score 37.0, average score 69.5
# episode898: score -45.5, average score 68.4
# Saving...
# episode899: score -12.5, average score 67.9
# episode900: score -1.7, average score 67.6
# episode901: score 251.6, average score 69.8
# episode902: score -113.9, average score 66.4
# episode903: score 271.3, average score 68.5
# episode904: score -27.2, average score 68.3
# episode905: score 245.7, average score 71.1
# episode906: score 19.4, average score 70.8
# episode907: score 41.1, average score 70.7
# episode908: score 160.6, average score 70.4
# episode909: score -28.4, average score 70.0
# episode910: score 53.1, average score 71.2
# episode911: score 55.1, average score 72.5
# episode912: score 226.6, average score 74.1
# episode913: score -74.3, average score 73.3
# episode914: score -7.6, average score 71.4
# episode915: score -2.8, average score 72.3
# episode916: score 195.0, average score 75.0
# episode917: score 234.8, average score 78.1
# episode918: score 11.9, average score 78.9
# episode919: score 49.8, average score 81.1
# episode920: score 46.2, average score 81.4
# episode921: score 236.4, average score 81.1
# episode922: score 258.7, average score 82.9
# episode923: score 46.9, average score 83.9
# episode924: score -14.4, average score 84.3
# episode925: score -23.2, average score 84.8
# episode926: score 13.7, average score 85.8
# episode927: score -18.5, average score 85.3
# episode928: score -40.4, average score 83.9
# episode929: score 7.9, average score 82.8
# episode930: score 219.2, average score 85.0
# episode931: score 262.8, average score 86.2
# episode932: score 278.5, average score 87.3
# episode933: score 224.3, average score 90.4
# episode934: score 256.3, average score 91.4
# episode935: score -73.9, average score 87.9
# episode936: score -45.6, average score 85.6
# episode937: score -25.3, average score 83.6
# episode938: score -52.0, average score 82.5
# episode939: score -10.9, average score 83.0
# episode940: score 187.2, average score 84.4
# episode941: score 14.1, average score 85.4
# episode942: score 220.0, average score 87.6
# episode943: score -36.5, average score 87.2
# episode944: score 14.1, average score 87.2
# episode945: score 28.7, average score 87.9
# episode946: score 2.3, average score 88.6
# episode947: score -18.3, average score 88.2
# episode948: score 14.4, average score 87.9
# episode949: score 212.4, average score 90.5
# episode950: score 223.4, average score 93.4
# episode951: score 202.7, average score 95.0
# episode952: score 20.5, average score 93.0
# episode953: score -29.3, average score 89.9
# episode954: score -38.0, average score 89.1
# episode955: score 291.1, average score 92.2
# episode956: score -24.9, average score 92.2
# episode957: score 213.2, average score 91.6
# episode958: score -19.7, average score 88.8
# episode959: score -46.0, average score 87.7
# episode960: score -65.9, average score 87.4
# episode961: score 2.8, average score 87.2
# episode962: score 6.5, average score 85.6
# episode963: score -3.4, average score 85.3
# episode964: score 27.1, average score 83.2
# episode965: score 144.9, average score 84.2
# episode966: score 22.9, average score 82.5
# episode967: score -6.6, average score 79.8
# episode968: score -27.0, average score 79.2
# episode969: score 13.1, average score 77.0
# episode970: score 5.0, average score 74.8
# episode971: score 225.0, average score 77.4
# episode972: score 242.8, average score 77.2
# episode973: score 225.7, average score 77.0
# episode974: score -52.4, average score 73.9
# episode975: score -25.2, average score 71.2
# episode976: score 9.4, average score 71.4
# episode977: score -37.9, average score 69.0
# episode978: score -51.3, average score 65.9
# episode979: score -13.8, average score 65.4
# episode980: score -1.5, average score 62.9
# episode981: score -13.9, average score 63.1
# episode982: score 9.1, average score 63.0
# episode983: score 3.4, average score 62.9
# episode984: score 158.4, average score 64.3
# episode985: score 220.8, average score 66.9
# episode986: score 18.3, average score 66.9
# episode987: score 5.4, average score 64.3
# episode988: score 187.3, average score 66.0
# episode989: score 9.2, average score 63.8
# episode990: score 128.7, average score 65.6
# episode991: score -15.5, average score 63.6
# episode992: score 8.7, average score 61.1
# episode993: score 211.9, average score 61.2
# episode994: score -11.7, average score 60.6
# episode995: score -19.8, average score 60.1
# episode996: score 6.4, average score 60.6
# episode997: score 5.0, average score 60.3
# episode998: score -10.0, average score 60.7
# Saving...
# episode999: score 175.2, average score 62.6
# episode1000: score 18.3, average score 62.8
# episode1001: score 249.1, average score 62.7
# episode1002: score -44.7, average score 63.4
# episode1003: score 35.9, average score 61.1
# episode1004: score -56.1, average score 60.8
# episode1005: score -102.3, average score 57.3
# episode1006: score -32.4, average score 56.8
# episode1007: score -134.2, average score 55.0
# episode1008: score -217.4, average score 51.2
# episode1009: score -25.8, average score 51.3
# episode1010: score -120.1, average score 49.5
# episode1011: score 20.9, average score 49.2
# episode1012: score -170.7, average score 45.2
# episode1013: score -29.3, average score 45.7
# episode1014: score -37.7, average score 45.4
# episode1015: score -38.7, average score 45.0
# episode1016: score 38.4, average score 43.4
# episode1017: score -168.3, average score 39.4
# episode1018: score -38.0, average score 38.9
# episode1019: score -74.1, average score 37.7
# episode1020: score -46.1, average score 36.8
# episode1021: score -12.3, average score 34.3
# episode1022: score -200.5, average score 29.7
# episode1023: score -74.8, average score 28.5
# episode1024: score -17.9, average score 28.4
# episode1025: score -9.4, average score 28.6
# episode1026: score 10.1, average score 28.5
# episode1027: score -14.2, average score 28.6
# episode1028: score -59.8, average score 28.4
# episode1029: score -38.5, average score 27.9
# episode1030: score -80.2, average score 24.9
# episode1031: score -165.7, average score 20.6
# episode1032: score -72.8, average score 17.1
# episode1033: score -19.0, average score 14.7
# episode1034: score -29.3, average score 11.8
# episode1035: score -27.2, average score 12.3
# episode1036: score -120.7, average score 11.5
# episode1037: score -57.1, average score 11.2
# episode1038: score 13.2, average score 11.9
# episode1039: score -101.1, average score 11.0
# episode1040: score -69.4, average score 8.4
# episode1041: score -72.2, average score 7.5
# episode1042: score 35.4, average score 5.7
# episode1043: score -68.6, average score 5.4
# episode1044: score -19.7, average score 5.0
# episode1045: score -64.7, average score 4.1
# episode1046: score -56.0, average score 3.5
# episode1047: score -97.7, average score 2.7
# episode1048: score 19.8, average score 2.8
# episode1049: score -75.2, average score -0.1
# episode1050: score 12.8, average score -2.2
# episode1051: score 8.7, average score -4.1
# episode1052: score -97.1, average score -5.3
# episode1053: score -82.5, average score -5.8
# episode1054: score -92.1, average score -6.4
# episode1055: score -58.8, average score -9.9
# episode1056: score 198.7, average score -7.6
# episode1057: score -102.0, average score -10.8
# episode1058: score -50.7, average score -11.1
# episode1059: score -64.0, average score -11.3
# episode1060: score -53.6, average score -11.2
# episode1061: score 4.9, average score -11.1
# episode1062: score -77.6, average score -12.0
# episode1063: score -106.8, average score -13.0
# episode1064: score -54.3, average score -13.8
# episode1065: score -21.7, average score -15.5
# episode1066: score 15.6, average score -15.6
# episode1067: score -3.4, average score -15.5
# episode1068: score -81.6, average score -16.1
# episode1069: score -25.2, average score -16.5
# episode1070: score -11.8, average score -16.6
# episode1071: score -7.5, average score -19.0
# episode1072: score -20.3, average score -21.6
# episode1073: score -96.6, average score -24.8
# episode1074: score -10.4, average score -24.4
# episode1075: score 185.5, average score -22.3
# episode1076: score -27.9, average score -22.7
# episode1077: score -12.7, average score -22.4
# episode1078: score -58.2, average score -22.5
# episode1079: score -21.3, average score -22.6
# episode1080: score 196.2, average score -20.6
# ...
# episode1649: score 230.8, average score 158.0
# episode1650: score -4.7, average score 155.6
# episode1651: score 257.6, average score 155.8
# episode1652: score 278.4, average score 156.1
# episode1653: score 16.8, average score 156.0
# episode1654: score 248.4, average score 158.9
# episode1655: score 44.8, average score 159.2
# episode1656: score 298.6, average score 159.8
# episode1657: score -17.5, average score 159.8
# episode1658: score 23.6, average score 157.9
# episode1659: score -68.4, average score 154.8
# episode1660: score -101.2, average score 151.9
# episode1661: score -116.2, average score 148.6
# episode1662: score -93.3, average score 148.0
# episode1663: score -42.2, average score 145.3
# episode1664: score -61.1, average score 142.0
# episode1665: score -71.4, average score 138.8
# episode1666: score -81.2, average score 137.8
# episode1667: score -44.9, average score 135.2
# episode1668: score -33.1, average score 132.4
# episode1669: score -38.2, average score 129.6
# episode1670: score -64.7, average score 128.8
# episode1671: score -54.3, average score 128.2
# episode1672: score -54.6, average score 127.5
# episode1673: score 8.5, average score 126.2
# episode1674: score -53.9, average score 125.5
# episode1675: score -41.5, average score 122.8
# episode1676: score 4.8, average score 122.9
# episode1677: score -58.3, average score 120.0
# episode1678: score -47.5, average score 118.3
# episode1679: score -27.7, average score 115.4
# episode1680: score -39.1, average score 115.0
# episode1681: score -53.4, average score 114.3
# episode1682: score -39.1, average score 114.3
# episode1683: score -34.4, average score 111.6
# episode1684: score -12.3, average score 109.2
# episode1685: score 9.6, average score 109.3
# episode1686: score 8.4, average score 109.0
# episode1687: score -60.8, average score 106.2
# episode1688: score -38.9, average score 103.5
# episode1689: score -31.0, average score 103.3
# episode1690: score -69.9, average score 102.5
# episode1691: score -29.5, average score 100.0
# episode1692: score -49.3, average score 96.9
# episode1693: score -39.8, average score 96.3
# episode1694: score -12.9, average score 93.3
# episode1695: score -60.3, average score 92.9
# episode1696: score -46.5, average score 89.9
# episode1697: score -56.6, average score 87.1
# episode1698: score -34.7, average score 84.5
# Saving...
# episode1699: score -53.1, average score 81.7
# episode1700: score -54.8, average score 78.9
# episode1701: score -66.2, average score 76.1
# episode1702: score -61.2, average score 73.2
# episode1703: score -54.0, average score 70.1
# episode1704: score -42.2, average score 69.3
# episode1705: score -48.9, average score 68.6
# episode1706: score -36.1, average score 66.8
# episode1707: score -11.9, average score 64.1
# episode1708: score -28.4, average score 61.2
# episode1709: score -55.8, average score 58.2
# episode1710: score -49.3, average score 55.2
# episode1711: score 5.4, average score 52.7
# episode1712: score -86.0, average score 49.4
# episode1713: score -69.7, average score 46.0
# episode1714: score -27.6, average score 43.4
# episode1715: score -70.2, average score 42.4
# episode1716: score -52.0, average score 42.3
# episode1717: score -36.3, average score 39.4
# episode1718: score -19.6, average score 36.7
# episode1719: score 24.9, average score 34.4
# episode1720: score 60.7, average score 33.0
# episode1721: score -47.1, average score 31.9
# episode1722: score -3.2, average score 29.6
# episode1723: score -31.1, average score 26.4
# episode1724: score 5.2, average score 24.0
# episode1725: score 33.7, average score 21.4
# episode1726: score 22.5, average score 22.1
# episode1727: score 273.5, average score 25.0
# episode1728: score -29.4, average score 21.8
# episode1729: score -45.3, average score 18.8
# episode1730: score -38.6, average score 16.9
# episode1731: score -23.0, average score 14.5
# episode1732: score 20.4, average score 12.0
# episode1733: score 25.9, average score 12.4
# episode1734: score 20.8, average score 9.9
# episode1735: score -15.8, average score 7.4
# episode1736: score -29.1, average score 4.5
# episode1737: score -51.9, average score 1.5
# episode1738: score 258.3, average score 1.8
# episode1739: score -56.8, average score -0.1
# episode1740: score 51.4, average score 0.4
# episode1741: score -8.2, average score -2.3
# episode1742: score 247.3, average score -2.2
# episode1743: score -51.3, average score -5.4
# episode1744: score 254.6, average score 4.3
# episode1745: score -15.0, average score 1.9
# episode1746: score -26.5, average score -0.9
# episode1747: score -19.5, average score -3.3
# episode1748: score -60.6, average score -6.2
# episode1749: score -5.3, average score -8.6
# episode1750: score -51.2, average score -9.1
# episode1751: score -63.3, average score -12.3
# episode1752: score 36.6, average score -14.7
# episode1753: score 16.6, average score -14.7
# episode1754: score -99.6, average score -18.2
# episode1755: score 44.1, average score -18.2
# episode1756: score -5.6, average score -21.2
# episode1757: score -25.5, average score -21.3
# episode1758: score 269.8, average score -18.9
# episode1759: score -26.8, average score -18.4
# episode1760: score -153.9, average score -19.0
# episode1761: score 28.1, average score -17.5
# episode1762: score -6.6, average score -16.7
# episode1763: score -52.6, average score -16.8
# episode1764: score -29.0, average score -16.4
# episode1765: score 271.2, average score -13.0
# episode1766: score -51.8, average score -12.7
# episode1767: score -92.3, average score -13.2
# episode1768: score -61.6, average score -13.5
# episode1769: score 306.6, average score -10.0
# episode1770: score -28.7, average score -9.7
# episode1771: score -18.6, average score -9.3
# episode1772: score 284.2, average score -5.9
# episode1773: score 258.6, average score -3.4
# episode1774: score 254.8, average score -0.3
# episode1775: score 253.9, average score 2.6
# episode1776: score 22.0, average score 2.8
# episode1777: score 209.3, average score 5.5
# episode1778: score 270.3, average score 8.6
# episode1779: score -3.0, average score 8.9
# episode1780: score -39.0, average score 8.9
# episode1781: score -42.0, average score 9.0
# episode1782: score 244.7, average score 11.8
# episode1783: score 248.2, average score 14.7
# episode1784: score -27.0, average score 14.5
# episode1785: score -47.3, average score 14.0
# episode1786: score 16.6, average score 14.0
# episode1787: score -32.6, average score 14.3
# episode1788: score 239.6, average score 17.1
# episode1789: score 174.5, average score 19.2
# episode1790: score 4.2, average score 19.9
# episode1791: score 267.3, average score 22.9
# episode1792: score 265.9, average score 26.0
# episode1793: score 127.9, average score 27.7
# episode1794: score 246.2, average score 30.3
# episode1795: score 12.5, average score 31.0
# episode1796: score -8.7, average score 31.4
# episode1797: score -19.8, average score 31.8
# episode1798: score -2.2, average score 32.1
# Saving...
# episode1799: score 244.3, average score 35.1
# episode1800: score 244.8, average score 38.1
# episode1801: score 222.7, average score 40.9
# episode1802: score 0.8, average score 41.6
# episode1803: score -42.3, average score 41.7
# episode1804: score 263.6, average score 44.7
# episode1805: score 259.8, average score 47.8
# episode1806: score 297.9, average score 51.2
# episode1807: score -18.7, average score 51.1
# episode1808: score -7.9, average score 51.3
# episode1809: score 249.7, average score 54.4
# episode1810: score -29.7, average score 54.6
# episode1811: score 221.8, average score 56.7
# episode1812: score 7.2, average score 57.7
# episode1813: score 245.2, average score 60.8
# episode1814: score -6.9, average score 61.0
# episode1815: score 17.8, average score 61.9
# episode1816: score 261.8, average score 65.0
# episode1817: score -84.4, average score 64.5
# episode1818: score 265.4, average score 67.4
# episode1819: score 262.0, average score 69.8
# episode1820: score -36.5, average score 68.8
# episode1821: score 188.1, average score 71.1
# episode1822: score 240.2, average score 73.6
# episode1823: score 229.9, average score 76.2
# episode1824: score 229.2, average score 78.4
# episode1825: score 227.5, average score 80.4
# episode1826: score -22.0, average score 79.9
# episode1827: score 123.6, average score 78.4
# episode1828: score -14.9, average score 78.6
# episode1829: score 250.4, average score 81.5
# episode1830: score -27.6, average score 81.6
# episode1831: score 253.6, average score 84.4
# episode1832: score -9.4, average score 84.1
# episode1833: score 240.2, average score 86.2
# episode1834: score 248.0, average score 88.5
# episode1835: score 228.9, average score 91.0
# episode1836: score 135.7, average score 92.6
# episode1837: score 259.1, average score 95.7
# episode1838: score 231.1, average score 95.5
# episode1839: score 214.5, average score 98.2
# episode1840: score 11.6, average score 97.8
# episode1841: score 154.9, average score 99.4
# episode1842: score 223.9, average score 99.2
# episode1843: score 111.1, average score 100.8
# episode1844: score 216.7, average score 100.4
# episode1845: score 222.3, average score 102.8
# episode1846: score 234.9, average score 105.4
# episode1847: score 177.5, average score 107.4
# episode1848: score 221.2, average score 110.2
# episode1849: score 207.4, average score 112.3
# episode1850: score 255.1, average score 115.4
# episode1851: score 223.2, average score 118.2
# episode1852: score 60.1, average score 118.5
# episode1853: score 179.0, average score 120.1
# episode1854: score 259.1, average score 123.7
# episode1855: score 236.6, average score 125.6
# episode1856: score 275.7, average score 128.4
# episode1857: score -12.4, average score 128.6
# episode1858: score 200.4, average score 127.9
# episode1859: score -10.0, average score 128.0
# episode1860: score 167.7, average score 131.2
# episode1861: score 256.5, average score 133.5
# episode1862: score 2.7, average score 133.6
# episode1863: score 252.1, average score 136.7
# episode1864: score 243.0, average score 139.4
# episode1865: score 168.2, average score 138.4
# episode1866: score 248.9, average score 141.4
# episode1867: score 93.3, average score 143.2
# episode1868: score 177.2, average score 145.6
# episode1869: score 183.3, average score 144.4
# episode1870: score 169.1, average score 146.4
# episode1871: score 250.4, average score 149.0
# episode1872: score 236.2, average score 148.6
# episode1873: score 259.6, average score 148.6
# episode1874: score 231.6, average score 148.3
# episode1875: score 152.1, average score 147.3
# episode1876: score -55.8, average score 146.5
# episode1877: score -32.6, average score 144.1
# episode1878: score 6.4, average score 141.5
# episode1879: score 216.2, average score 143.7
# episode1880: score 176.7, average score 145.8
# episode1881: score 5.4, average score 146.3
# episode1882: score 248.1, average score 146.3
# episode1883: score 252.4, average score 146.4
# episode1884: score 198.3, average score 148.6
# episode1885: score 192.0, average score 151.0
# episode1886: score 221.0, average score 153.1
# episode1887: score 202.0, average score 155.4
# episode1888: score 235.5, average score 155.4
# episode1889: score 276.6, average score 156.4
# episode1890: score 150.6, average score 157.9
# episode1891: score 206.4, average score 157.3
# episode1892: score 204.5, average score 156.6
# episode1893: score -63.9, average score 154.7
# episode1894: score 255.3, average score 154.8
# episode1895: score 243.0, average score 157.1
# episode1896: score 218.0, average score 159.4
# episode1897: score 276.3, average score 162.4
# episode1898: score 238.3, average score 164.8
# Saving...
# episode1899: score -9.1, average score 162.2
# episode1900: score 259.1, average score 162.4
# episode1901: score 8.6, average score 160.2
# episode1902: score -44.5, average score 159.8
# episode1903: score -18.6, average score 160.0
# episode1904: score 18.4, average score 157.6
# episode1905: score 0.3, average score 155.0
# episode1906: score 4.4, average score 152.0
# episode1907: score -26.3, average score 152.0
# episode1908: score -46.7, average score 151.6
# episode1909: score -36.2, average score 148.7
# episode1910: score -41.3, average score 148.6
# episode1911: score -30.7, average score 146.1
# episode1912: score -53.9, average score 145.5
# episode1913: score -29.1, average score 142.7
# episode1914: score 29.6, average score 143.1
# episode1915: score 5.6, average score 143.0
# episode1916: score 8.3, average score 140.4
# episode1917: score -41.8, average score 140.8
# episode1918: score -30.5, average score 137.9
# episode1919: score -58.1, average score 134.7
# episode1920: score -43.1, average score 134.6
# episode1921: score -37.0, average score 132.4
# episode1922: score -71.2, average score 129.2
# episode1923: score -20.5, average score 126.7
# episode1924: score -67.2, average score 123.8
# episode1925: score -11.7, average score 121.4
# episode1926: score -18.5, average score 121.4
# episode1927: score -35.8, average score 119.8
# episode1928: score -56.9, average score 119.4
# episode1929: score 222.7, average score 119.1
# episode1930: score -5.3, average score 119.4
# episode1931: score 213.2, average score 119.0
# episode1932: score 19.5, average score 119.2
# episode1933: score 231.1, average score 119.1
# episode1934: score 233.6, average score 119.0
# episode1935: score 3.0, average score 116.7
# episode1936: score 16.8, average score 115.6
# episode1937: score -20.1, average score 112.8
# episode1938: score 255.8, average score 113.0
# episode1939: score 246.9, average score 113.3
# episode1940: score 244.3, average score 115.7
# episode1941: score 33.8, average score 114.4
# episode1942: score 239.3, average score 114.6
# episode1943: score 271.0, average score 116.2
# episode1944: score 264.1, average score 116.7
# episode1945: score -1.3, average score 114.4
# episode1946: score -0.2, average score 112.1
# episode1947: score 248.3, average score 112.8
# episode1948: score -7.5, average score 110.5
# episode1949: score -22.5, average score 108.2
# episode1950: score 235.8, average score 108.0
# episode1951: score 265.8, average score 108.4
# episode1952: score 198.5, average score 109.8
# episode1953: score 40.0, average score 108.4
# episode1954: score 287.1, average score 108.7
# episode1955: score 2.5, average score 106.4
# episode1956: score 17.8, average score 103.8
# episode1957: score 277.4, average score 106.7
# episode1958: score 249.5, average score 107.2
# episode1959: score -5.5, average score 107.2
# episode1960: score 259.4, average score 108.1
# episode1961: score -4.5, average score 105.5
# episode1962: score 257.2, average score 108.1
# episode1963: score 229.8, average score 107.9
# episode1964: score 260.8, average score 108.0
# episode1965: score 28.4, average score 106.6
# episode1966: score 214.5, average score 106.3
# episode1967: score -18.7, average score 105.2
# episode1968: score 280.0, average score 106.2
# episode1969: score 29.9, average score 104.7
# episode1970: score 232.2, average score 105.3
# episode1971: score 264.2, average score 105.4
# episode1972: score -26.5, average score 102.8
# episode1973: score 206.8, average score 102.3
# episode1974: score 187.3, average score 101.8
# episode1975: score 233.0, average score 102.7
# episode1976: score 197.2, average score 105.2
# episode1977: score 47.3, average score 106.0
# episode1978: score 254.2, average score 108.5
# episode1979: score 7.9, average score 106.4
# episode1980: score 211.1, average score 106.7
# episode1981: score 20.7, average score 106.9
# episode1982: score 206.6, average score 106.5
# episode1983: score 234.5, average score 106.3
# episode1984: score -36.6, average score 103.9
# episode1985: score 125.1, average score 103.3
# episode1986: score -46.8, average score 100.6
# episode1987: score -69.3, average score 97.9
# episode1988: score -40.5, average score 95.1
# episode1989: score -7.2, average score 92.3
# episode1990: score 18.4, average score 91.0
# episode1991: score 202.6, average score 90.9
# episode1992: score 1.1, average score 88.9
# episode1993: score 160.0, average score 91.1
# episode1994: score 201.8, average score 90.6
# episode1995: score 218.9, average score 90.3
# episode1996: score 249.9, average score 90.7
# episode1997: score 32.1, average score 88.2
# episode1998: score 222.9, average score 88.1
# Saving...
# episode1999: score 82.7, average score 89.0
# --- Training: 68.91453161833333 minutes ---

# %%
def test_ppo(ep):
    agent.load_models(ep)
    rendered_frames = []
    for i in range(3):
        state = env.reset()
        for j in range(2000):
            action = agent.choose_action(state)[0]
#             env.render()
            rendered_frames.append(env.render(mode='rgb_array'))
            state, reward, done, _ = env.step(action)
            if done:
                env.reset()
                break
    env.close()
    return rendered_frames

# %%
def save_video(rendered_frames, ep):
    
    # For ios
#     plt.rcParams['animation.ffmpeg_path'] = '/Users/celineyin/opt/anaconda3/envs/machinelearning/bin/ffmpeg'

    plt.ioff()
    fig = plt.figure(figsize=(rendered_frames[0].shape[1] / 72.0,
                              rendered_frames[0].shape[0] / 72.0), dpi = 72)
    ax = fig.add_subplot(111)
    patch = ax.imshow(rendered_frames[0])
    plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False,
                    right=False, labelbottom=False, labelleft=False)
    def animate(i):
        patch.set_data(rendered_frames[i])
    
    anim = animation.FuncAnimation(fig, animate, frames=len(rendered_frames), interval=20, repeat=True)

    Writer = animation.writers['ffmpeg']
    writer = Writer(fps=50, metadata=dict(artist='Me'), bitrate=1800)
    
    filename = str(int(ep*100)) + '.mp4' 
    rela_dir_test = dir_video[-9:] + '/' + filename
    anim.save(rela_dir_test, writer=writer, dpi=100)

    HTML(anim.to_html5_video())

# %%
start = time.time()
env = gym.make('LunarLander-v2')
agent = Agent(n_actions=env.action_space.n, input_dims=env.observation_space.shape)
end = time.time()
print('Time Taken to Train: ', end-start)
# Out:
# Time Taken to Train:  0.006276845932006836

# %%
# print the phrase wanted, test to get the frames, then save its test video
to_be_save = 1
rendered_frames = test_ppo(ep=to_be_save)
save_video(rendered_frames, ep=to_be_save)
# Out:
# Loading...

# %%
'''RUN CELL AND UNCOMMENT LAST LINE IF MODEL HAS BEEN TRAINED, OTHERWISE IGNORE'''
df_PPO = pd.DataFrame()
df_PPO['Reward'] = score_history
df_PPO['time'] = time_ppo

df_PPO.to_csv('PPO Rewards.csv')

# %%
env.close()

# %% [markdown]
# ### Random Agent

# %%
def Random_games(env, num_episodes):
    
    rewards = []
    # Each of this episode is its own game.
    for episode in range(num_episodes):
        env.reset()
        episode_reward = 0

        while True:
            action = env.action_space.sample()

            next_state, reward, done, info = env.step(action)
            episode_reward += reward
                  
            if done:
                rewards.append(episode_reward)
                break
                
    results['RandomAgent'] = np.array(rewards) #dict

# %%
Random_games(lunar_env, num_episodes)

# %%
'''RUN CELL AND UNCOMMENT LAST LINE IF MODEL HAS BEEN TRAINED, OTHERWISE IGNORE'''
df_RA = pd.DataFrame()
df_RA['Reward'] = results['RandomAgent']
df_RA.to_csv('RandomAgent Rewards.csv')

# %% [markdown]
# ### Comparision Between Four Agents

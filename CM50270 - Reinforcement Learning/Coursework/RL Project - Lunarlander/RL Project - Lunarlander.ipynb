# %% [markdown]
# # CM50270 Reinforcement Learning Project
#
# ### Lunar Lander V2

# %% [markdown]
# ## Importing Dependencies

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import time
from collections import deque
import gym

import tensorflow.compat.v1 as tf
from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Dense, Embedding, Reshape, Lambda
from tensorflow.keras.optimizers import Adam

from matplotlib import animation, rc
from matplotlib.animation import FuncAnimation
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay
from IPython.display import HTML, clear_output

# %%
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only
import random
import math
import glob
import logging
import io
import base64

import keras
import tensorflow as tf2
from keras import backend as K

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions.categorical import Categorical
import timeit

# %% [markdown]
# #### Agent Videos
# Define helper functions to extract videos of the agent's performance.

# %%
def render(episode, env, m_name, n_ep):
   """ This function is for covert frames data to mp4 and save it"""
    
    fig = plt.figure()
    img = plt.imshow(env.render(mode='rgb_array'))
    plt.axis('off')

    def animate(i):
        img.set_data(episode[i])
        return img,
    
    mp4 = os.getcwd() + '/' + str(m_name) + ' Videos/' + str(m_name) + '_' + str(n_ep) +'.mp4'
    anim = FuncAnimation(fig, animate, frames=len(episode), interval=1, blit=True)
    Writer = animation.writers['ffmpeg']
    writer = Writer(fps = 50, metadata = dict(artist = 'Me'), bitrate = 1800)
    anim.save(mp4, writer = writer, dpi=100)

    html =  HTML(anim.to_html5_video())

    plt.close(fig)
    
    return html

def save_video(episodes_frames, methods, env):
     """ This function is for save the video one by one"""

    path = os.getcwd() + '/' + methods + ' Videos'
    if not os.path.exists(path):
        os.makedirs(path)
        
    for i in range(len(episodes_frames)):
        render(episodes_frames[i], env, methods, i)

# %% [markdown]
# ## ⭐ 1. REINFORCE Algorithm with Adaptive Baseline

# %% [markdown]
# Implement *Agent*

# %%
class RLAgent(object):
    
    def __init__(self, obs_space, action_space, policy_learning_rate, value_learning_rate, 
                 discount, baseline = None, num_layers=3, ma_window_size=50):

        # input/output
        self.num_obs = obs_space  
        self.num_act = action_space.n
        
        # training parameters
        self.plr = policy_learning_rate
        self.vlr = value_learning_rate
        self.gamma = discount
        self.num_layers = num_layers
        self.ma_window_size = ma_window_size
    
        # lists to store the cumulative observations for an episode
        self.eps_observations = []
        self.eps_actions = []
        self.eps_rewards = []

        # set baseline
        if baseline == 'adaptive':
            self.use_adaptive_baseline = True
        else:
            self.use_adaptive_baseline = False

        # build the keras network/s
        self.network()

    def observe(self, state, action, reward):
        """ This function takes the observations the agent received from the environment and stores them
            in the lists above."""

        self.eps_observations.append(state)
        self.eps_actions.append(action)
        self.eps_rewards.append(reward)
        
    def get_action(self, state):
        """ This function feeds the observed state to the network, which returns a distribution
            over possible actions. Sample an action from the distribution and return it."""

        # get actions probabilities
        state = state.reshape([1, self.num_obs])
        
        action_probabilities = self.model(state).numpy().flatten()
     
        # sample an action
        action = np.random.choice(self.num_act, p=action_probabilities)

        return action

    def train(self):
        """ When this function is called, the accumulated episode observations, actions and discounted rewards
            should be fed into the network and used for training. Use the _get_returns function to first turn 
            the episode rewards into discounted returns. 
            Apply simple or adaptive baselines if needed, depending on parameters."""

        episode_length = len(self.eps_observations)

        # States
        obs_states=np.array(self.eps_observations)

        # Actions (hot encoding)
        mask = np.eye(self.num_act) #unit matric
        actions = mask[self.eps_actions]

        # Discounted Rewards
        discounted_rewards = np.array(self.returns())
                    
        if self.use_adaptive_baseline:
            
            # update model_baseline parameters
            self.model_baseline.train_on_batch(x = obs_states, y = discounted_rewards)
            
            # subtract Baseline
            discounted_rewards -= self.model_baseline(obs_states).numpy().flatten() #advantage
        
        # update model (policy) parameters weights
        self.model.train_on_batch(x = obs_states, y = actions, sample_weight = discounted_rewards)
        
        # reset cumulative lists
        self.eps_observations = []
        self.eps_actions = []
        self.eps_rewards = []

    def returns(self):
        """ This function should process self.episode_rewards and return the discounted episode returns
            at each step in the episode. """ 
               
        discounted_rewards = []
        cum_return = 0

        #a[::-1] reverse the list
        for r in self.eps_rewards[::-1]:  
            cum_return = (cum_return*self.gamma) + r
            discounted_rewards.insert(0, cum_return) #insert as the first value
    
        return discounted_rewards


    def network(self):
        """ This function should build the network that can then be called by decide and train. 
            The network takes observations as inputs and has a policy distribution as output."""

        model = Sequential()
        for i in tf2.range(self.num_layers):
            model.add(Dense(16, activation="relu"))
        model.add(Dense(self.num_act, activation="softmax")) 
        
        model.compile(loss = "categorical_crossentropy", optimizer = Adam(learning_rate=self.plr))
        self.model = model

        if self.use_adaptive_baseline == True:
            model_baseline = Sequential()
            for i in tf2.range(self.num_layers):
                  model_baseline.add(Dense(16, activation="relu"))
            model_baseline.add(Dense(1)) 
        
            model_baseline.compile(loss = "mse", optimizer = Adam(learning_rate=self.vlr))
            self.model_baseline = model_baseline

# %% [markdown]
# Implement functions to run and test the agent in the environment.

# %%
def run_experiment(experiment_name, env, num_episodes, policy_learning_rate=0.001, value_learning_rate=0.001, baseline=None, 
                   num_layers=3):

    #Initiate the learning agent
    agent = RLAgent(obs_space=env.observation_space.shape[0], action_space=env.action_space, policy_learning_rate=policy_learning_rate, 
                    value_learning_rate=value_learning_rate, discount=0.99, baseline=baseline, num_layers=num_layers)

    rewards = []
    all_eps_frames = []
    step = 0
    time_list = []
    count = 0
    
    #loop each episode
    for episode in range(1, num_episodes+1):
    
        #Update results plot and occasionally store an episode movie
        eps_frames = None
        start = time.time()

        if (episode < 10) or (episode>=989 and episode<=999) or (episode>=1989 and episode<=1999):
            eps_frames = []
            
        #initialise, Reset the environment to a new episode
        observation = env.reset()
        episode_reward = 0
        
        #loop each step 
        while True:
            
            #occasionally store an episode movie
            if eps_frames is not None:
                eps_frames.append(env.render(mode='rgb_array'))

            # 1. Decide on an next action based on the observations
            action = agent.get_action(observation)

            # 2. Take action in the environment
            next_observation, reward, done, info = env.step(action)
            episode_reward += reward

            # 3. Store the information returned from the environment for training the model
            agent.observe(observation, action, reward)
            
#             if count % 20 == 0:
#                 agent.train()

            # 4. When we reach a terminal state ("done"), use the observed episode to train the network
            if done:
                end = time.time()
                time_list.append(end - start)
                
                rewards.append(episode_reward)
                if episode % 10 == 0:
                    print("episode: {}/{}, reward: {}".format(episode, num_episodes, episode_reward))
                    
                if eps_frames is not None:
                    all_eps_frames.append(eps_frames)
                    
                if (episode % 100 == 0) or episode == 1:
                    agent.model.save(('REINFORCE Networks/reinforce_model_{}'.format(count)))
                    count += 1
                
                agent.train() #each epo done then train the model
                break

            # Reset for next step
            observation = next_observation
            step += 1
            
    results[experiment_name] = np.array(rewards)
    
    return all_eps_frames, agent, time_list

# %%
def test_experiment(env, num_episodes, policy_learning_rate=0.001, value_learning_rate=0.001, baseline=None, 
                   num_layers=3, file = ''):
    
    lunar_env = env
    agent = RLAgent(obs_space=lunar_env.observation_space.shape[0], action_space=lunar_env.action_space, policy_learning_rate=policy_learning_rate, 
                    value_learning_rate=value_learning_rate, discount=0.99, baseline=baseline, num_layers=num_layers)
      
    rf_model = tf.keras.models.load_model(file)
    step = 0
    agent.model = rf_model
    
    rewards, average_reward, all_eps_frames = [], [], []
   
    eps_frames = None

    #loop each episode
    for episode in range(1, num_episodes+1):
        eps_frames = []
            
        #initialise, Reset the environment to a new episode
        observation = lunar_env.reset()
        episode_reward = 0
        
        #loop each step 
        while True:
            #occasionally store an episode movie
            if eps_frames is not None:
                eps_frames.append(env.render(mode='rgb_array'))

            # 1. Decide on an next action based on the observations
            action = agent.get_action(observation)

            # 2. Take action in the environment
            next_observation, reward, done, info = env.step(action)
            episode_reward += reward


            # 4. When we reach a terminal state ("done"), use the observed episode to train the network
            if done:
                rewards.append(episode_reward)
                print("episode: {}/{}, reward: {}".format(episode, num_episodes, episode_reward))
                    
                if eps_frames is not None:
                    all_eps_frames.append(eps_frames)
             
                break

            # Reset for next step
            observation = next_observation
            step += 1
    
    return all_eps_frames, np.array(rewards)

# %% [markdown]
# ### Gym Setup
#
# Here we load the Reinforcement Learning environments from OpenAI's Gym.
#
# We limit each episode to 500 steps so that we can train faster.

# %%
num_episodes = 2000

# %%
lunar_env = gym.make('LunarLander-v2')
lunar_env._max_episode_steps = 1000

# %matplotlib inline
plt.rcParams['figure.figsize'] = 12, 8

# %% [markdown]
# ### Train the Agent

# %%
results = {}

# %%
policy_learning_rate = 0.0025
value_learning_rate = 0.005

# REINFORCE + Adaptive Baseline reduce the variance of the updates by subtracting a baseline function
episodes_reinforce, d_model, time_reinforce = run_experiment("REINFORCE (adaptive baseline)", lunar_env, num_episodes, policy_learning_rate, 
                                   value_learning_rate, baseline='adaptive')
# Out:
# INFO:tensorflow:Assets written to: REINFORCE Networks/reinforce_model_0\assets
# episode: 10/100, reward: -106.26648570020569
# episode: 20/100, reward: -198.05531552084636
# episode: 30/100, reward: -367.41823371848795
# episode: 40/100, reward: -446.99766112712024
# episode: 50/100, reward: -218.8249185292961
# episode: 60/100, reward: -291.5602088797184
# episode: 70/100, reward: -151.8824745112764
# episode: 80/100, reward: -170.41211852827087
# episode: 90/100, reward: -279.84922911696094
# episode: 100/100, reward: -377.3976783225836
# INFO:tensorflow:Assets written to: REINFORCE Networks/reinforce_model_1\assets

# %%
# save_video(episodes_reinforce, 'REINFORCE', lunar_env)

# %% [markdown]
# Store rewards and episode time.

# %%
'''RUN CELL AND UNCOMMENT LAST LINE IF MODEL HAS BEEN TRAINED, OTHERWISE IGNORE'''
df_RF = pd.DataFrame()
df_RF['Reward'] = results['REINFORCE (adaptive baseline)']
df_RF['time'] = time_reinforce
df_RF.to_csv('REINFORCE Rewards.csv')

# %% [markdown]
# Save the Videos

# %%
#test the model and get frame data for each frames 
policy_learning_rate = 0.0025
value_learning_rate = 0.005

test_0,rewards_0 =test_experiment(lunar_env, 3, policy_learning_rate, value_learning_rate, baseline='adaptive', \
                file = 'REINFORCE Networks/reinforce_model_0')

test_20,rewards_20 =test_experiment(lunar_env, 3, policy_learning_rate, value_learning_rate, baseline='adaptive', \
                file = 'REINFORCE Networks/reinforce_model_20')
# Out:
# episode: 1/3, reward: -325.52938858634474
# episode: 2/3, reward: -195.43846677740152
# episode: 3/3, reward: -136.57354419641854
# episode: 1/3, reward: 108.4041626559185
# episode: 2/3, reward: 119.07667376263993
# episode: 3/3, reward: 127.88522982939573

# %%
#concat 3 episodes data to one 
episodes_reinforce_test = []

episodes_clip = []
for i in range(3):
    episodes_clip += test_0[i]
episodes_reinforce_test.append(episodes_clip)

episodes_clip = []
for i in range(3):
    episodes_clip += test_20[i]
episodes_reinforce_test.append(episodes_clip)

# %%
lunar_env.close()

# %%
save_video(episodes_reinforce_test, 'REINFORCE test', lunar_env)

# %% [markdown]
# ## ⭐ 2. DDQN (Double DQN) Algorithm with Experience Replay

# %%
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /Users/emtiazsamad/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/tensorflow_core/python/compat/v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# Implement *Agent*

# %%
def network(opt, input_dim, action_size):
    network = Sequential()
    network.add(Dense(128, input_dim = input_dim, activation = "relu"))
    network.add(Dense(128, activation = "relu"))
    network.add(Dense(action_size, activation = "linear"))
    network.compile(optimizer = opt, loss = 'mse')
    return network

class DDQNAgent:
    def __init__(self, env, optimizer, batch_size, gamma=0.99, epsilon=1, decay=0.995):
        self.env = env
        self.optimizer = optimizer
        self.batch_size = batch_size
        self.gamma = gamma
        self.epsilon = epsilon
        self.decay = decay
        
        self.state_size = env.observation_space.shape[0]
        self.action_size = env.action_space.n
        
        self.exp_replay = deque(maxlen=1000000)
        
        self.qnetwork = network(self.optimizer, self.state_size, self.action_size)
        self.target = network(self.optimizer, self.state_size, self.action_size)
        
        self.rewards = None
        self.average_reward = None
        self.ep_time = []
        self.cumulative_time = []

    def policy(self, state):
        if np.random.random() < self.epsilon:
            action = np.random.choice(self.action_size)
        else:
            state = np.reshape(state, [1, self.state_size])
            actions = self.qnetwork.predict(state)
            action = np.argmax(actions[0])
        return action
    
    def add_memory(self, state, action, reward, next_state, terminal):
        self.exp_replay.append((state, action, reward, next_state, terminal))
    
    def update_target(self):
        return self.target.set_weights(self.qnetwork.get_weights())
    
    def train(self):
        batch_size = min(len(self.exp_replay), self.batch_size)
        batch = random.sample(self.exp_replay, batch_size)
        
        states = np.ndarray((batch_size, self.state_size))
        next_states = states.copy()
        
        actions = np.ndarray((batch_size, 1))
        rewards = actions.copy()
        terminals = actions.copy()
        
        step = 0
        for memory in batch:
            states[step], actions[step], rewards[step], next_states[step], terminals[step] = memory
            step += 1
         
        q_next = self.target.predict(next_states) * (np.ones(shape = terminals.shape) - terminals)
        q_next = np.max(q_next, axis=1)
        q = self.qnetwork.predict(states)
        
        for i in range(batch_size):
            q[i,int(actions[i,0])] = rewards[i] + self.gamma * q_next[i]
            
        self.qnetwork.fit(states, q, verbose = 0)
    
    def train_model(self, env, num_episodes):
        
        count = 0
        rewards, average_reward = [], []
        
        
        average = deque(maxlen=100)
        
        txt = open('Saved Networks.txt', 'w')
        path = os.getcwd() + '/Saved Networks'
        if not os.path.exists(path):
            os.makedirs(path)
        
        cumulative_start = time.time()

        for episode in range(1, num_episodes + 1):
            ep_start = time.time()
            state = env.reset()
            total = 0
            terminal = False
            
            while not terminal:
                action = self.policy(state)
                next_state, reward, terminal, _ = env.step(action)
                
                total += reward
                
                self.add_memory(state, action, reward, next_state, terminal)
                self.train()
                state = next_state
                
        
            average.append(total)
            average_reward.append(np.mean(average))
            rewards.append(total)

            self.update_target()
            self.epsilon = max(0.1, self.decay * self.epsilon)
            ep_end = time.time()
            self.ep_time.append(ep_end - ep_start)
            
            cumulative_end = time.time()
            self.cumulative_time.append(cumulative_end - cumulative_start)
            
            if episode % 10 == 0:
                print(f'Episode {episode}: {total}')
            
            if (episode % 100 == 0) or episode == 1:
                self.qnetwork.save(('Saved Networks/ddqn_model_{0}'.format(count)))
                txt.write("Save {0} - Episode {1}, Reward: {2}, Average Reward: {3}\n".format(count, 
                                                                                          episode, 
                                                                                          total, 
                                                                                          np.mean(average)))
                count += 1

        self.rewards = rewards
        self.average_reward = average_reward
        
    def test_model(self, env, num_episodes, file):
        self.qnetwork = tf.keras.models.load_model(file)
        self.epsilon = 0
        
        count = 0
        rewards, average_reward, all_eps_frames = [], [], []
        average = deque(maxlen=100)
        eps_frames = None
        
        for episode in range(1, num_episodes + 1):
            state = env.reset()
            total = 0
            eps_frames = []
            terminal = False
            
            while not terminal:
                action = self.policy(state)
                next_state, reward, terminal, _ = env.step(action)
                
                eps_frames.append(env.render(mode='rgb_array'))
                
                total += reward                
                state = next_state
                
                if terminal:
                    all_eps_frames.append(eps_frames)
            
            average.append(total)
            average_reward.append(np.mean(average))
            rewards.append(total)
            print(f'Episode {episode}: {total}')

        self.rewards = rewards
        self.average_reward = average_reward

        return all_eps_frames
        
    def plot_results(self):
        plt.figure(figsize = (10, 6), dpi = 100)

        plt.plot(self.rewards, alpha = 0.7, label = 'Rewards')
        plt.plot(self.average_reward, 'red', label = 'Average Rewards')
        plt.axhline(y = 200, color = 'orange', linestyle = '-', label = 'Threshold')
        
        plt.xlim(0, len(self.rewards))
        plt.title('Learning Curve', fontweight = 'bold')
        plt.xlabel('Episode', fontweight = 'bold')
        plt.ylabel('Reward', fontweight = 'bold')
        plt.legend(loc = 'lower right')

# %%
env = gym.make("LunarLander-v2")
optimizer = Adam(learning_rate = 0.0001)
agent = DDQNAgent(env, optimizer, batch_size = 64)
# Out:
# WARNING:tensorflow:From /Users/emtiazsamad/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# /Users/emtiazsamad/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_util.py:521: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   tensor_proto.tensor_content = nparray.tostring()
# /Users/emtiazsamad/opt/anaconda3/envs/datascience/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_utils.py:1293: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   if isinstance(sample_weight_mode, collections.Mapping):

# %%
agent.train_model(env, num_episodes = num_episodes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35896/1641383295.py in <module>
# ----> 1 agent.train_model(env, num_episodes = num_episodes)
#
# NameError: name 'agent' is not defined

# %% [markdown]
# ## Storing Rewards per Episode in DataFrame and Saving as CSV File

# %%
'''RUN CELL AND UNCOMMENT LAST LINE IF MODEL HAS BEEN TRAINED, OTHERWISE IGNORE'''
df = pd.DataFrame()
df['Reward'] = agent.rewards
df['Average Reward'] = agent.average_reward
df['Time'] = agent.ep_time
df['Cumulative Time'] = agent.cumulative_time
df.to_csv('DDQN Rewards.csv')

# %% [markdown]
# ## Reloading Instance with Saved Rewards and Plotting Train Results

# %%
df = pd.read_csv('DDQN Rewards.csv')
env = gym.make("LunarLander-v2")
optimizer = Adam(learning_rate = 0.0001)

agent_plt = DDQNAgent(env, optimizer, batch_size = 64)
agent_plt.rewards = df['Reward']
agent_plt.average_reward = df['Average Reward']
agent_plt.plot_results()

# %% [markdown]
# ## Testing Models and Recording Performance at Varying Number of Episodes Trained

# %%
env = gym.make("LunarLander-v2")
optimizer = Adam(learning_rate = 0.0001)

episodes_ddqn = []

agent_test = DDQNAgent(env, optimizer, batch_size = 64)
print('2000 Episodes Trained')
test = agent_test.test_model(env, 3, 'Saved Networks/ddqn_model_20')

episodes_clip = []
for i in range(3):
    episodes_clip += test[i]
episodes_ddqn.append(episodes_clip)
# Out:
# 2000 Episodes Trained
# Episode 1: 293.70857334976165
# Episode 2: 273.43203487498573
# Episode 3: 231.02335347238812

# %%
env.close()

# %%
save_video(episodes_ddqn, 'DDQN', env)

# %% [markdown]
# ## ⭐ 3. PPO(Proximal Policy Optimization) Algorithm with Experience Replay

# %% [markdown]
# Implement *Agent*

# %%
# Part of this code is inspired by - https://github.com/philtabor/Youtube-Code-Repository/tree/master/ReinforcementLearning/PolicyGradient/PPO/torch

class PPO_Buffer:
    def __init__(self, batch_size):
        self.states = []
        self.actions = []
        self.logprobs = []
        self.values = []
        self.rewards = []
        self.dones = []  # terminal flags
        self.batch_size = batch_size

    # randomly pick one from the buffers that have been stored and shuffled
    def pick_batch(self):
        n_states = len(self.states)
        batch_start = np.arange(0, n_states, self.batch_size)
        indices = np.arange(n_states, dtype=np.int64)
        np.random.shuffle(indices)
        batches = [indices[i: i+self.batch_size] for i in batch_start]

        return np.array(self.states), np.array(self.actions), np.array(self.logprobs), \
                  np.array(self.values), np.array(self.rewards), np.array(self.dones), batches

    def save_buffer(self, state, action, logprob, value, reward, done):
        self.states.append(state)
        self.actions.append(action)
        self.logprobs.append(logprob)
        self.values.append(value)
        self.rewards.append(reward)
        self.dones.append(done)

    def clear_buffer(self):
        self.states.clear()
        self.actions.clear()
        self.logprobs.clear()
        self.values.clear()
        self.rewards.clear()
        self.dones.clear()

# %%
class ActorNetwork(nn.Module):
    def __init__(self, n_actions, input_d, alpha, fc1_d=256, fc2_d=256, fc3_d=128):
        super(ActorNetwork, self).__init__()

        self.actor = nn.Sequential(
            nn.Linear(*input_d, fc1_d),
            nn.ReLU(),
            nn.Linear(fc1_d, fc2_d),
            nn.ReLU(),
            nn.Linear(fc2_d, fc3_d),
            nn.ReLU(),
            nn.Linear(fc3_d, n_actions),
            nn.Softmax(dim=-1),
        )
        self.optimizer = optim.Adam(self.parameters(), lr=alpha)

    def forward(self, state):
        return Categorical(self.actor(state))


class CriticNetwork(nn.Module):
    def __init__(self, input_d, alpha, fc1_d=256, fc2_d=256, fc3_d=128):
        super(CriticNetwork, self).__init__()
        self.critic = nn.Sequential(
            nn.Linear(*input_d, fc1_d),
            nn.ReLU(),
            nn.Linear(fc1_d, fc2_d),
            nn.ReLU(),
            nn.Linear(fc2_d, fc3_d),
            nn.ReLU(),
            nn.Linear(fc3_d, 1),
        )
        self.optimizer = optim.Adam(self.parameters(), lr=alpha)

    def forward(self, state):
        return self.critic(state)

# %%
class Agent:
    def __init__(self, n_actions, input_dims, gamma=0.99, alpha=3e-4, gae=0.95, clip=0.2, batch_size=5, n_epochs=4):
        # initialize parameters
        self.gamma = gamma
        self.clip = clip
        self.n_epochs = n_epochs
        self.gae = gae

        self.buffer = PPO_Buffer(batch_size)
        self.actor = ActorNetwork(n_actions, input_dims, alpha)
        self.critic = CriticNetwork(input_dims, alpha)


    def choose_action(self, observation):
        state = torch.tensor(np.array([observation]), dtype=torch.float).to(device)
        # give distribution from neural network for choosing an action
        dist = self.actor(state)
        value = self.critic(state)
        action = dist.sample()

        prob = torch.squeeze(dist.log_prob(action)).item()
        action = torch.squeeze(action).item()
        value = torch.squeeze(value).item()

        return action, prob, value

    def learn(self):
        for _ in range(self.n_epochs):
            s, a, old_p, v, r, dones, batches = self.buffer.pick_batch()
            advantage = np.zeros(len(r))

            for t in range(len(r)-1):
                discount = 1
                advantage_t = 0
                for k in range(t, len(r)-1):
                    # calculate accumalated advantage value for each t
                    advantage_t += discount*(r[k] + self.gamma*v[k+1] * (1 - int(dones[k])) - v[k])
                    discount *= self.gamma * self.gae
                advantage[t] = advantage_t
            advantage = torch.tensor(advantage).to(device)
            values = torch.tensor(v).to(device)

            for b in batches:
                # store into torch's tensor processor
                states = torch.tensor(s[b], dtype=torch.float).to(device)
                old_probs = torch.tensor(old_p[b]).to(device)
                actions = torch.tensor(a[b]).to(device)

                dist = self.actor(states)
                critic_value = torch.squeeze(self.critic(states))

                new_probs = dist.log_prob(actions)
                weighted_probs = advantage[b] * (new_probs - old_probs).exp()
                weighted_clipped_probs = torch.clamp((new_probs - old_probs).exp(), 1-self.clip, 1+self.clip) * advantage[b]
                actor_loss = - torch.min(weighted_probs, weighted_clipped_probs).mean()
                critic_loss = ((advantage[b] + values[b] - critic_value) ** 2).mean()
                total_loss = actor_loss + critic_loss/2

                # do gradient ascent for rewarding, do gradient descent for loss
                self.actor.optimizer.zero_grad()
                self.critic.optimizer.zero_grad()
                total_loss.backward()
                self.actor.optimizer.step()
                self.critic.optimizer.step()

        self.buffer.clear_buffer()

    def save_models(self, ep):
        print('Saving...')
        torch.save(self.actor.state_dict(), 'ppo_model/actor_ppo_{}.h5'.format(ep))
        torch.save(self.critic.state_dict(), 'ppo_model/critic_ppo_{}.h5'.format(ep))

    def load_models(self, ep):
        print('Loading...')
        self.actor.load_state_dict(torch.load('ppo_model/actor_ppo_{}.h5'.format(ep)))
        self.critic.load_state_dict(torch.load('ppo_model/critic_ppo_{}.h5'.format(ep)))

# %%
def train_agent(n_episodes):
    start_time = timeit.default_timer()
    n_episodes = n_episodes
    score_history = []
    n_steps = 0
    time_list = []
    count = 0
    
    for i in range(n_episodes):
        observation = env.reset()
        done = False
        score = 0
        start = time.time()
            
        while not done:
            action, prob, value = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            n_steps += 1
            score += reward
            # interface between agent and its memory
            agent.buffer.save_buffer(observation, action, prob, value, reward, done)
            
            if n_steps % 20 == 0:
                agent.learn()
            observation = observation_
            
            if done:
                end = time.time()
                time_list.append(end - start)
                
        score_history.append(score)
        mean_score = np.mean(score_history[-100:])
        
        if (i+1)%100==0 or i==0:
            agent.save_models(count)
            count += 1

        print('episode{}: score {:.1f}, average score {:.1f}'.format(i, score, mean_score))
    print("--- Training: %s minutes ---" % ((timeit.default_timer() - start_time)/60))

    return score_history, time_list

# %% [markdown]
# Test models

# %%
def test_ppo(num_episodes, env, file = 0):
    
    agent.load_models(file)
    
    env = env
    start_time = timeit.default_timer()
    n_episodes = num_episodes
    best_score = env.reward_range[0]
    score_history = []
    n_steps = 0
    
    rendered_frames = []

    for i in range(n_episodes):
        observation = env.reset()
        done = False
        score = 0
        eps_frames = []
            
        while not done:
            action, prob, value = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            n_steps += 1
            score += reward
            # interface between agent and its memory
            agent.buffer.save_buffer(observation, action, prob, value, reward, done)
            
             
            if eps_frames is not None:
                eps_frames.append(env.render(mode='rgb_array'))
            
            if done:
                if eps_frames is not None:
                    rendered_frames.append(eps_frames)
                    
            observation = observation_
                        
        score_history.append(score)
        mean_score = np.mean(score_history[-100:])
        print('episode{}: score {:.1f}, average score {:.1f}'.format(i, score, mean_score))

    print("--- Training: %s minutes ---" % ((timeit.default_timer() - start_time)/60))

    return score_history, rendered_frames

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
methods = 'ppo'
dir_model = os.getcwd() + '/' + methods + '_model'
dir_video = os.getcwd() + '/' + methods + '_video'

if not os.path.exists(dir_model):
    os.makedirs(dir_model)
if not os.path.exists(dir_video):
    os.makedirs(dir_video)

# %%
# train to save the model
env = gym.make('LunarLander-v2')
agent = Agent(n_actions=env.action_space.n, input_dims=env.observation_space.shape)
score_history, time_ppo = train_agent(n_episodes=num_episodes)
# Out:
# Saving...
# episode0: score -162.3, average score -162.3
# episode1: score -310.2, average score -236.3
# episode2: score -191.6, average score -221.4
# episode3: score -308.7, average score -243.2
# episode4: score -208.6, average score -236.3
# episode5: score -162.6, average score -224.0
# episode6: score -32.1, average score -196.6
# episode7: score -194.4, average score -196.3
# episode8: score -192.4, average score -195.9
# episode9: score -106.8, average score -187.0
# episode10: score -233.3, average score -191.2
# episode11: score -7.9, average score -175.9
# episode12: score -286.0, average score -184.4
# episode13: score -175.4, average score -183.7
# episode14: score -351.2, average score -194.9
# episode15: score -69.2, average score -187.0
# episode16: score -279.1, average score -192.5
# episode17: score -99.9, average score -187.3
# episode18: score -151.5, average score -185.4
# episode19: score -456.5, average score -199.0
# episode20: score -116.9, average score -195.1
# episode21: score -160.0, average score -193.5
# episode22: score -380.2, average score -201.6
# episode23: score -400.5, average score -209.9
# episode24: score -277.5, average score -212.6
# episode25: score -448.4, average score -221.7
# episode26: score -134.3, average score -218.4
# episode27: score -359.1, average score -223.5
# episode28: score -193.6, average score -222.4
# episode29: score -207.3, average score -221.9
# episode30: score -392.2, average score -227.4
# episode31: score -242.1, average score -227.9
# episode32: score -170.2, average score -226.1
# episode33: score -137.8, average score -223.5
# episode34: score -220.0, average score -223.4
# episode35: score -169.0, average score -221.9
# episode36: score -234.6, average score -222.3
# episode37: score 0.3, average score -216.4
# episode38: score -468.8, average score -222.9
# episode39: score -337.4, average score -225.7
# episode40: score -225.8, average score -225.7
# episode41: score -42.8, average score -221.4
# episode42: score -327.7, average score -223.9
# episode43: score -60.2, average score -220.1
# episode44: score -432.7, average score -224.9
# episode45: score -228.8, average score -224.9
# episode46: score -93.5, average score -222.2
# episode47: score -115.9, average score -219.9
# episode48: score -71.8, average score -216.9
# episode49: score -80.0, average score -214.2
# episode50: score -85.8, average score -211.7
# episode51: score -100.5, average score -209.5
# episode52: score -45.8, average score -206.4
# episode53: score -150.4, average score -205.4
# episode54: score -87.0, average score -203.2
# episode55: score -58.8, average score -200.7
# episode56: score -166.7, average score -200.1
# episode57: score 6.9, average score -196.5
# episode58: score -505.8, average score -201.7
# episode59: score -265.1, average score -202.8
# episode60: score -220.2, average score -203.1
# episode61: score -119.6, average score -201.7
# episode62: score -34.0, average score -199.1
# episode63: score -32.0, average score -196.5
# episode64: score -219.1, average score -196.8
# episode65: score -254.1, average score -197.7
# episode66: score -224.8, average score -198.1
# episode67: score -36.0, average score -195.7
# episode68: score -52.4, average score -193.6
# episode69: score -18.6, average score -191.1
# episode70: score -102.3, average score -189.9
# episode71: score -111.7, average score -188.8
# episode72: score -244.4, average score -189.6
# episode73: score -103.6, average score -188.4
# episode74: score -25.9, average score -186.2
# episode75: score -72.0, average score -184.7
# episode76: score -62.4, average score -183.1
# episode77: score -7.4, average score -180.9
# episode78: score -124.6, average score -180.2
# episode79: score -264.2, average score -181.2
# episode80: score 42.4, average score -178.5
# episode81: score 140.5, average score -174.6
# episode82: score -187.6, average score -174.7
# episode83: score -219.1, average score -175.2
# episode84: score -157.8, average score -175.0
# episode85: score -171.4, average score -175.0
# episode86: score -124.7, average score -174.4
# episode87: score -50.8, average score -173.0
# episode88: score -80.7, average score -172.0
# episode89: score -97.7, average score -171.2
# episode90: score -262.0, average score -172.2
# episode91: score -125.6, average score -171.6
# episode92: score -128.1, average score -171.2
# episode93: score -169.3, average score -171.2
# episode94: score -44.4, average score -169.8
# episode95: score -82.5, average score -168.9
# episode96: score -83.8, average score -168.0
# episode97: score -99.5, average score -167.3
# episode98: score 7.2, average score -165.6
# Saving...
# episode99: score -45.3, average score -164.4
# --- Training: 8.175516210000008 minutes ---

# %%
env = gym.make('LunarLander-v2')
agent = Agent(n_actions=env.action_space.n, input_dims=env.observation_space.shape)

rewards_0, test_0  = test_ppo(3, env, file = 0)

rewards_20, test_20  = test_ppo(3, env, file = 20)
# Out:
# Saving...
# episode0: score -97.3, average score -97.3
# episode1: score -114.8, average score -106.0
# episode2: score -133.9, average score -115.3
# --- Training: 1.9748762550000039 minutes ---
# Saving...
# episode0: score -122.2, average score -122.2
# episode1: score -132.3, average score -127.3
# episode2: score -109.2, average score -121.3
# --- Training: 2.259442391666668 minutes ---

# %%
episodes_ppo_test = []

episodes_clip = []
for i in range(3):
    episodes_clip += test_0[i]
episodes_ppo_test.append(episodes_clip)
    
episodes_clip = []
for i in range(3):
    episodes_clip += test_20[i]
    
episodes_ppo_test.append(episodes_clip)

# %%
save_video(episodes_ppo_test, 'PPO test', env)

# %%
'''RUN CELL AND UNCOMMENT LAST LINE IF MODEL HAS BEEN TRAINED, OTHERWISE IGNORE'''
df_PPO = pd.DataFrame()
df_PPO['Reward'] = score_history
df_PPO['time'] = time_ppo

df_PPO.to_csv('PPO Rewards.csv')

# %%
env.close()

# %% [markdown]
# ### Random Agent

# %%
def Random_games(env, num_episodes):
    
    rewards = []
    # Each of this episode is its own game.
    for episode in range(num_episodes):
        env.reset()
        episode_reward = 0

        while True:
            action = env.action_space.sample()

            next_state, reward, done, info = env.step(action)
            episode_reward += reward
                  
            if done:
                rewards.append(episode_reward)
                break
                
    results['RandomAgent'] = np.array(rewards) #dict

# %%
Random_games(lunar_env, num_episodes)

# %%
'''RUN CELL AND UNCOMMENT LAST LINE IF MODEL HAS BEEN TRAINED, OTHERWISE IGNORE'''
df_RA = pd.DataFrame()
df_RA['Reward'] = results['RandomAgent']
df_RA.to_csv('RandomAgent Rewards.csv')

# %% [markdown]
# ### Results: Comparision Between Four Agents

# %%
res_RA = pd.read_csv('RandomAgent Rewards.csv')
res_RF = pd.read_csv('REINFORCE Rewards.csv')
res_DD = pd.read_csv('DDQN Rewards.csv')
res_PPO = pd.read_csv('PPO Rewards.csv')

# %%
res_all = pd.DataFrame()
res_time = pd.DataFrame()

res_all['RandomAgent'] = res_RA['Reward']
res_all['REINFORCE'] = res_RF['Reward']
res_all['DDQN'] = res_DD['Reward']
res_all['PPO'] = res_PPO['Reward']

res_time['REINFORCE'] = res_RF['time']
res_time['DDQN'] = res_DD['Time']
res_time['PPO'] = res_PPO['time']

# %%
plt.rcParams['figure.figsize'] = 12, 8

# %%
#plot the results
window = 10

color_list = ['seagreen', 'blue', 'purple', 'orangered']

for k, v in enumerate(res_all.columns.to_list()):
    y = np.convolve(res_all[v], np.ones((window,))/window, mode='valid')
    x = np.linspace(window/2, len(res_all[v]) - window/2, len(y))
    plt.plot(x, y, label=v, color = color_list[k])

plt.xlabel('Episode', size=15)
plt.ylabel('Reward', size=15)
plt.legend(loc='lower right')
plt.axhline(y = 200, color = 'black', linestyle = '--', label = 'Threshold')
plt.title('Learning Curve', size=20)

for k, v in enumerate(res_all.columns.to_list()):
    y = res_all[v]
    x = np.linspace(window/2, len(res_all[v]) - window/2, len(y))
    plt.plot(x, y, label=v, alpha = .2 ,color = color_list[k])

# %%
for k, v in enumerate(res_time.columns.to_list()):
    y = res_time[v].cumsum()
    x = np.linspace(window/2, len(res_time[v]) - window/2, len(y))
    plt.plot(x, y, label=v, alpha = 1 ,color = color_list[k])
    
plt.xlabel('Episode', size=15)
plt.ylabel('Time(s)', size=15)
plt.legend(loc='lower right')
# plt.axhline(y = 200, color = 'black', linestyle = '--', label = 'Threshold')
plt.title('Cumulative Time Duration for Each Episode', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Cumulative Time Duration for Each Episode')
